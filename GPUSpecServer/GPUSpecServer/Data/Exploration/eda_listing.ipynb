# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv("../Source/Clean/2025-08.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3120 entries, 0 to 3119
# Data columns (total 54 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   manufacturer                      3120 non-null   object
#  1   name                              3120 non-null   object
#  2   gpu_name                          3120 non-null   object
#  3   generation                        3120 non-null   object
#  4   base_clock_mhz                    3120 non-null   float64
#  5   boost_clock_mhz                   3120 non-null   float64
#  6   architecture                      3092 non-null   object
#  7   foundry                           2995 non-null   object
#  8   process_size_nm                   3116 non-null   float64
#  9   transistor_count_m                2877 non-null   float64
#  10  transistor_density_k_mm2          2846 non-null   float64
#  11  die_size_mm2                      2912 non-null   float64
#  12  chip_package                      1858 non-null   object
#  13  release_date                      3055 non-null   object
#  14  bus_interface                     3071 non-null   object
#  15  memory_clock_mhz                  2654 non-null   float64
#  16  memory_size_gb                    3120 non-null   float64
#  17  memory_bus_bits                   2654 non-null   float64
#  18  memory_bandwidth_gb_s             2654 non-null   float64
#  19  memory_type                       3120 non-null   object
#  20  shading_units                     3120 non-null   int64
#  21  texture_mapping_units             3120 non-null   int64
#  22  render_output_processors          3120 non-null   int64
#  23  streaming_multiprocessors         3120 non-null   int64
#  24  tensor_cores                      3120 non-null   int64
#  25  ray_tracing_cores                 3120 non-null   int64
#  26  l1_cache_kb                       3120 non-null   float64
#  27  l2_cache_mb                       3120 non-null   float64
#  28  thermal_design_power_w            2405 non-null   float64
#  29  board_length_mm                   1059 non-null   float64
#  30  board_width_mm                    556 non-null    float64
#  31  board_slot_width                  2768 non-null   object
#  32  suggested_psu_w                   1644 non-null   float64
#  33  power_connectors                  758 non-null    object
#  34  display_connectors                1504 non-null   object
#  35  directx_major_version             3017 non-null   float64
#  36  directx_minor_version             3017 non-null   float64
#  37  opengl_major_version              3000 non-null   float64
#  38  opengl_minor_version              3000 non-null   float64
#  39  vulkan_major_version              1453 non-null   float64
#  40  vulkan_minor_version              1453 non-null   float64
#  41  opencl_major_version              2153 non-null   float64
#  42  opencl_minor_version              2153 non-null   float64
#  43  cuda_major_version                1054 non-null   float64
#  44  cuda_minor_version                1054 non-null   float64
#  45  shader_model_major_version        2512 non-null   float64
#  46  shader_model_minor_version        2512 non-null   float64
#  47  pixel_rate_gpixel_s               3120 non-null   float64
#  48  texture_rate_gtexel_s             3120 non-null   float64
#  49  half_float_performance_gflop_s    945 non-null    float64
#  50  single_float_performance_gflop_s  2288 non-null   float64
#  51  double_float_performance_gflop_s  1682 non-null   float64
#  52  tpu_id                            3120 non-null   object
#  53  tpu_url                           3120 non-null   object
# dtypes: float64(33), int64(6), object(15)
# memory usage: 1.3+ MB

# %%
nan_columns = df.columns[df.isnull().any()]

print("Columns with NaN values:")
print(nan_columns)
# Out:
# Columns with NaN values:
# Index(['architecture', 'foundry', 'process_size_nm', 'transistor_count_m',
#        'transistor_density_k_mm2', 'die_size_mm2', 'chip_package',
#        'release_date', 'bus_interface', 'memory_clock_mhz', 'memory_bus_bits',
#        'memory_bandwidth_gb_s', 'thermal_design_power_w', 'board_length_mm',
#        'board_width_mm', 'board_slot_width', 'suggested_psu_w',
#        'power_connectors', 'display_connectors', 'directx_major_version',
#        'directx_minor_version', 'opengl_major_version', 'opengl_minor_version',
#        'vulkan_major_version', 'vulkan_minor_version', 'opencl_major_version',
#        'opencl_minor_version', 'cuda_major_version', 'cuda_minor_version',
#        'shader_model_major_version', 'shader_model_minor_version',
#        'half_float_performance_gflop_s', 'single_float_performance_gflop_s',
#        'double_float_performance_gflop_s'],
#       dtype='object')

# %%
def get_association_len(df, parent, child):
    options = df.groupby([child])[parent].unique()
    count = df.groupby([child])[parent].nunique()
    
    association_df = pd.DataFrame(data={f'{parent}':options, 'count':count})
    association_df = association_df[association_df['count']>1]
    return association_df.shape[0]

# %%
def get_association_df(df, parent, child):
    options = df.groupby([child])[parent].unique()
    count = df.groupby([child])[parent].nunique()
    
    association_df = pd.DataFrame(data={f'{parent}':options, 'count':count})
    association_df = association_df[association_df['count']>1]
    return association_df

# %%
def get_association_counts(df, first, second):
    association_counts_df = pd.DataFrame({'column':[], f'{first}_count':[], f'{second}_count':[], 'contains_null':[]})

    for column in df.columns:
        if column == first or column == second:
            continue
        association_count1 = get_association_len(df, column, first)
        association_count2 = get_association_len(df, column, second)
        
        isnull = df[column].isnull().any()
        
        new_row_data = {'column':column, f'{first}_count': association_count1, f'{second}_count': association_count2, 'contains_null': isnull}
        association_counts_df.loc[len(association_counts_df)] = new_row_data
    return association_counts_df

# %%
def get_association_counts_generalized(df, target_columns):
    target_columns = [col for col in target_columns if col in df.columns]

    output_cols = ['column']
    count_cols = {}
    for target_col in target_columns:
        col_name = f'{target_col}_count'
        output_cols.append(col_name)
        count_cols[target_col] = col_name
    output_cols.append('contains_null')

    association_counts_list = []

    for column in df.columns:
        if column in target_columns:
            continue

        new_row_data = {'column': column}

        for target_col in target_columns:
            association_count = get_association_len(df, column, target_col)
            new_row_data[count_cols[target_col]] = association_count

        isnull = df[column].isnull().any()
        new_row_data['contains_null'] = isnull

        association_counts_list.append(new_row_data)

    association_counts_df = pd.DataFrame(association_counts_list, columns=output_cols)
    return association_counts_df

# %% [markdown]
# **Create associations against product names to check what's unique to product name**

# %%
get_association_counts_generalized(df, ['architecture', 'gpu_name', 'generation', 'manufacturer', 'name'])
# Out:
#                               column  architecture_count  gpu_name_count  \
# 0                     base_clock_mhz                  69             319
# 1                    boost_clock_mhz                  76             354
# 2                            foundry                  14               2
# 3                    process_size_nm                  35               1
# 4                 transistor_count_m                  47               0
# 5           transistor_density_k_mm2                  48               1
# 6                       die_size_mm2                  52               1
# 7                       chip_package                  26               0
# 8                       release_date                  75             327
# 9                      bus_interface                  57             170
# 10                  memory_clock_mhz                  53             258
# 11                    memory_size_gb                  60             234
# 12                   memory_bus_bits                  48             131
# 13             memory_bandwidth_gb_s                  56             270
# 14                       memory_type                  49             138
# 15                     shading_units                  49             171
# 16             texture_mapping_units                  66             205
# 17          render_output_processors                  58             130
# 18         streaming_multiprocessors                  14              62
# 19                      tensor_cores                   6              22
# 20                 ray_tracing_cores                  13              41
# 21                       l1_cache_kb                  19              10
# 22                       l2_cache_mb                  34              90
# 23            thermal_design_power_w                  55             229
# 24                   board_length_mm                  41             111
# 25                    board_width_mm                  32              45
# 26                  board_slot_width                  43             140
# 27                   suggested_psu_w                  42             123
# 28                  power_connectors                  33              74
# 29                display_connectors                  46             165
# 30             directx_major_version                  10               0
# 31             directx_minor_version                   9               0
# 32              opengl_major_version                   5               0
# 33              opengl_minor_version                  12               0
# 34              vulkan_major_version                   0               0
# 35              vulkan_minor_version                   8               0
# 36              opencl_major_version                   5               0
# 37              opencl_minor_version                   9               0
# 38                cuda_major_version                   1               0
# 39                cuda_minor_version                  11               0
# 40        shader_model_major_version                   5               0
# 41        shader_model_minor_version                  10               0
# 42               pixel_rate_gpixel_s                  73             356
# 43             texture_rate_gtexel_s                  76             359
# 44    half_float_performance_gflop_s                  33             119
# 45  single_float_performance_gflop_s                  52             260
# 46  double_float_performance_gflop_s                  44             191
# 47                            tpu_id                  83             409
# 48                           tpu_url                  83             409
#
#     generation_count  manufacturer_count  name_count  contains_null
# 0                420                   8         139          False
# 1                448                   8         161          False
# 2                 51                   5          10           True
# 3                136                   8          46           True
# 4                268                   8          93           True
# 5                271                   7          97           True
# 6                279                   7         104           True
# 7                155                   4          54           True
# 8                379                   8         139           True
# 9                194                   7          36           True
# 10               352                   8          90           True
# 11               307                   8          54          False
# 12               231                   8          37           True
# 13               368                   8         107           True
# 14               191                   8          43          False
# 15               284                   4          54          False
# 16               344                   8          60          False
# 17               274                   8          48          False
# 18                92                   1          31          False
# 19                26                   1           0          False
# 20                50                   3           0          False
# 21                43                   4          10          False
# 22               184                   4          45          False
# 23               282                   6          49           True
# 24               117                   6           2           True
# 25                44                   5           0           True
# 26               134                   4          12           True
# 27               138                   5           7           True
# 28                77                   4           5           True
# 29               159                   7          19           True
# 30                65                   7          12           True
# 31                98                   6          18           True
# 32                20                   4           2           True
# 33                42                   6           3           True
# 34                 0                   0           0           True
# 35                19                   3           2           True
# 36                37                   3          17           True
# 37                45                   4          18           True
# 38                22                   1           9           True
# 39                44                   1          14           True
# 40                51                   4          12           True
# 41                70                   4          22           True
# 42               460                   8         168          False
# 43               464                   8         173          False
# 44               143                   3          43           True
# 45               332                   4         142           True
# 46               226                   4         100           True
# 47               507                   8         242          False
# 48               507                   8         242          False
