# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("../Source/Raw/2025-08.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3206 entries, 0 to 3205
# Data columns (total 54 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   manufacturer                      3206 non-null   object
#  1   name                              3206 non-null   object
#  2   gpu_name                          3206 non-null   object
#  3   generation                        3206 non-null   object
#  4   base_clock_mhz                    3206 non-null   float64
#  5   boost_clock_mhz                   3206 non-null   float64
#  6   architecture                      3178 non-null   object
#  7   foundry                           3081 non-null   object
#  8   process_size_nm                   3202 non-null   float64
#  9   transistor_count_m                2963 non-null   float64
#  10  transistor_density_k_mm2          2928 non-null   float64
#  11  die_size_mm2                      2994 non-null   float64
#  12  chip_package                      1927 non-null   object
#  13  release_date                      3140 non-null   object
#  14  bus_interface                     3157 non-null   object
#  15  memory_clock_mhz                  2740 non-null   float64
#  16  memory_size_gb                    3206 non-null   float64
#  17  memory_bus_bits                   2740 non-null   float64
#  18  memory_bandwidth_gb_s             2740 non-null   float64
#  19  memory_type                       3206 non-null   object
#  20  shading_units                     3206 non-null   int64
#  21  texture_mapping_units             3206 non-null   int64
#  22  render_output_processors          3206 non-null   int64
#  23  streaming_multiprocessors         3206 non-null   int64
#  24  tensor_cores                      3206 non-null   int64
#  25  ray_tracing_cores                 3206 non-null   int64
#  26  l1_cache_kb                       3206 non-null   float64
#  27  l2_cache_mb                       3206 non-null   float64
#  28  thermal_design_power_w            2486 non-null   float64
#  29  board_length_mm                   1118 non-null   float64
#  30  board_width_mm                    583 non-null    float64
#  31  board_slot_width                  2841 non-null   object
#  32  suggested_psu_w                   1705 non-null   float64
#  33  power_connectors                  782 non-null    object
#  34  display_connectors                1564 non-null   object
#  35  directx_major_version             3103 non-null   float64
#  36  directx_minor_version             3103 non-null   float64
#  37  opengl_major_version              3082 non-null   float64
#  38  opengl_minor_version              3082 non-null   float64
#  39  vulkan_major_version              1453 non-null   float64
#  40  vulkan_minor_version              1453 non-null   float64
#  41  opencl_major_version              2233 non-null   float64
#  42  opencl_minor_version              2233 non-null   float64
#  43  cuda_major_version                1077 non-null   float64
#  44  cuda_minor_version                1077 non-null   float64
#  45  shader_model_major_version        2594 non-null   float64
#  46  shader_model_minor_version        2594 non-null   float64
#  47  pixel_rate_gpixel_s               3206 non-null   float64
#  48  texture_rate_gtexel_s             3206 non-null   float64
#  49  half_float_performance_gflop_s    945 non-null    float64
#  50  single_float_performance_gflop_s  2369 non-null   float64
#  51  double_float_performance_gflop_s  1696 non-null   float64
#  52  tpu_id                            3206 non-null   object
#  53  tpu_url                           3206 non-null   object
# dtypes: float64(33), int64(6), object(15)
# memory usage: 1.3+ MB

# %%
nan_columns = df.columns[df.isnull().any()]

print("Columns with NaN values:")
print(nan_columns)
# Out:
# Columns with NaN values:
# Index(['architecture', 'foundry', 'process_size_nm', 'transistor_count_m',
#        'transistor_density_k_mm2', 'die_size_mm2', 'chip_package',
#        'release_date', 'bus_interface', 'memory_clock_mhz', 'memory_bus_bits',
#        'memory_bandwidth_gb_s', 'thermal_design_power_w', 'board_length_mm',
#        'board_width_mm', 'board_slot_width', 'suggested_psu_w',
#        'power_connectors', 'display_connectors', 'directx_major_version',
#        'directx_minor_version', 'opengl_major_version', 'opengl_minor_version',
#        'vulkan_major_version', 'vulkan_minor_version', 'opencl_major_version',
#        'opencl_minor_version', 'cuda_major_version', 'cuda_minor_version',
#        'shader_model_major_version', 'shader_model_minor_version',
#        'half_float_performance_gflop_s', 'single_float_performance_gflop_s',
#        'double_float_performance_gflop_s'],
#       dtype='object')

# %%
def get_association_df(df, parent, child):
    options = df.groupby([child])[parent].unique()
    count = df.groupby([child])[parent].nunique()
    
    association_df = pd.DataFrame(data={f'{parent}':options, 'count':count})
    association_df = association_df[association_df['count']>1]
    return association_df

# %%
#df['release_date'] = pd.to_datetime(df['release_date'])
#df.sort_values(by='release_date', ascending=False, inplace=True)
#df.drop_duplicates(subset=['name'], inplace=True)
#df

# %%
disp = get_association_df(df, 'manufacturer', 'architecture')

df = df[~((df['manufacturer']=='AMD') & (df['architecture']=='TeraScale'))] # remove all AMD manufactured chips from terascale architecture
df = df[~((df['manufacturer']=='ATI') & (df['architecture']=='TeraScale 2'))] # remove all ATI manufactured chips from terascale 2 architecture
df = df[~((df['manufacturer']=='AMD') & (df['architecture']=='Ultra-Threaded SE'))] # remove all AMD manufactured chips from UT SE architecture

disp
# Out:
#                   manufacturer  count
# architecture
# TeraScale           [ATI, AMD]      2
# TeraScale 2         [AMD, ATI]      2
# Ultra-Threaded SE   [ATI, AMD]      2

# %%
get_association_df(df, 'architecture', 'generation')
# Out:
#                                                 architecture  count
# generation
# All-In-One(Rx 200)           [TeraScale 2, GCN 1.0, GCN 3.0]      3
# All-In-One(Rx 300)                        [GCN 1.0, GCN 3.0]      2
# All-In-Wonder(2006 Edition)        [R300, Ultra-Threaded SE]      2
# All-In-Wonder(7000)                         [Rage 6, Rage 7]      2
# All-In-Wonder(9000)                           [R300, Rage 7]      2
# ...                                                      ...    ...
# Tesla Kepler(Kxx)                       [Kepler, Kepler 2.0]      2
# Tesla Maxwell(Mxx)                    [Maxwell 2.0, Maxwell]      2
# Volcanic Islands(R5 200)              [TeraScale 2, GCN 1.0]      2
# Volcanic Islands(R7 200)                  [GCN 1.0, GCN 2.0]      2
# Volcanic Islands(R9 200)         [GCN 1.0, GCN 3.0, GCN 2.0]      3
#
# [126 rows x 2 columns]

# %%
disp = get_association_df(df, 'architecture', 'gpu_name')

df[df['gpu_name']=='Condor']
df = df[~((df['gpu_name']=='Condor') & (df['architecture']=='G400'))] # remove all Condor chip products from G400 architecture
disp
# Out:
#           architecture  count
# gpu_name
# Condor    [G400, G500]      2

# %% [markdown]
# **Graphics**

# %%
disp = get_association_df(df, 'directx_major_version', 'gpu_name')
df = df[~((df['directx_major_version']==10.0) & (df['gpu_name']=='GT215'))] # remove the older GT215 chip product
disp
# Out:
#          directx_major_version  count
# gpu_name
# GT215             [10.0, 11.0]      2

# %%
disp = get_association_df(df, 'cuda_minor_version', 'gpu_name')
df = df[~((df['cuda_minor_version']==1.0) & (df['gpu_name']=='G92B'))] # remove the older G92B chip product
disp
# Out:
#          cuda_minor_version  count
# gpu_name
# G92B             [1.0, 3.0]      2

# %%
disp = get_association_df(df, 'generation', 'gpu_name')
disp
# Out:
#                                                  generation  count
# gpu_name
# 18800-1                                          [EGA, VGA]      2
# AD102     [GeForce 40, Server Ada(Lxx), Workstation Ada(...      3
# AD103     [GeForce 40, GeForce 40 Mobile, Workstation Ad...      4
# AD104     [GeForce 40, GeForce 40 Mobile, Server Ada(Lxx...      5
# AD106        [GeForce 40, GeForce 40 Mobile, Ada-MW(x000A)]      3
# ...                                                     ...    ...
# Vega 10   [Radeon Instinct(MIx), Radeon Pro Vega(Vega Se...      7
# Vega 20   [Radeon Instinct(MIx), Radeon Pro Vega(Vega II...      4
# Venus     [FirePro Mobile(Mx100), Solar System(HD 8800M)...      6
# Wani      [GCN 3.0 IGP(Carrizo Mobile), GCN 3.0 IGP(Bris...      2
# Whistler  [FirePro Mobile(Mx900), Embedded(6000), Vancou...      6
#
# [303 rows x 2 columns]

# %%
disp = get_association_df(df, 'name', 'generation')
disp
# Out:
#                                                                       name  \
# generation
# Ada-MW(x000A)            [RTX 2000 Embedded Ada Generation, RTX 2000 Ma...
# Alchemist(Arc 3 Mobile)                  [Arc A350M, Arc A370M, Arc A380M]
# Alchemist(Arc 3)                            [Arc A310, Arc A350, Arc A380]
# Alchemist(Arc 5 Mobile)                  [Arc A550M, Arc A530M, Arc A570M]
# Alchemist(Arc 7 Mobile)                             [Arc A730M, Arc A770M]
# ...                                                                    ...
# XG40(Volari 8000)                            [Volari 8300, Volari 8600 XT]
# XG40(Volari V3)                                  [Volari V3, Volari V3 XT]
# XG40(Volari V5)          [Volari Duo V5 Ultra, Volari V5, Volari V5 Ultra]
# XG40(Volari V8)          [Volari Duo V8 Ultra, Volari V8, Volari V8 Ultra]
# Xe Graphics                     [Iris Xe MAX Graphics, Xe DG1, Xe DG1-SDV]
#
#                          count
# generation
# Ada-MW(x000A)               13
# Alchemist(Arc 3 Mobile)      3
# Alchemist(Arc 3)             3
# Alchemist(Arc 5 Mobile)      3
# Alchemist(Arc 7 Mobile)      2
# ...                        ...
# XG40(Volari 8000)            2
# XG40(Volari V3)              2
# XG40(Volari V5)              3
# XG40(Volari V8)              3
# Xe Graphics                  3
#
# [503 rows x 2 columns]

# %%
disp = get_association_df(df, 'architecture', 'name')
disp
# Out:
#                                                                architecture  \
# name
# GMA 3000                                   [Generation 4.0, Generation 3.5]
# GeForce 610M                                             [Fermi 2.0, Fermi]
# GeForce 6200 AGP                                           [Celsius, Curie]
# GeForce 710A                                        [Fermi 2.0, Kepler 2.0]
# GeForce 710M                                        [Kepler 2.0, Fermi 2.0]
# ...                                                                     ...
# Radeon X1050                                                   [R300, R400]
# UHD Graphics 16EU Mobile  [Generation 11.0, Generation 12.1, Generation ...
# UHD Graphics 24EU Mobile  [Generation 9.5, Generation 11.0, Generation 1...
# UHD Graphics 32EU Mobile                 [Generation 11.0, Generation 12.1]
# UHD Graphics 730                         [Generation 12.1, Generation 12.2]
#
#                           count
# name
# GMA 3000                      2
# GeForce 610M                  2
# GeForce 6200 AGP              2
# GeForce 710A                  2
# GeForce 710M                  2
# ...                         ...
# Radeon X1050                  2
# UHD Graphics 16EU Mobile      3
# UHD Graphics 24EU Mobile      3
# UHD Graphics 32EU Mobile      2
# UHD Graphics 730              2
#
# [55 rows x 2 columns]

# %%
disp = get_association_df(df, 'manufacturer', 'name')
disp
# Out:
# Empty DataFrame
# Columns: [manufacturer, count]
# Index: []

# %%
disp = get_association_df(df, 'architecture', 'gpu_name')
disp
# Out:
# Empty DataFrame
# Columns: [architecture, count]
# Index: []

# %%
disp = get_association_df(df, 'manufacturer', 'gpu_name')
disp
# Out:
# Empty DataFrame
# Columns: [manufacturer, count]
# Index: []

# %%
disp = get_association_df(df, 'manufacturer', 'generation')
disp
# Out:
#                                manufacturer  count
# generation
# Console GPU(Microsoft)   [NVIDIA, ATI, AMD]      3
# Console GPU(Nintendo)    [ATI, AMD, NVIDIA]      3
# Console GPU(Sony)       [Sony, NVIDIA, AMD]      3

# %%
disp = get_association_df(df, 'generation', 'gpu_name')
disp
# Out:
#                                                  generation  count
# gpu_name
# 18800-1                                          [EGA, VGA]      2
# AD102     [GeForce 40, Server Ada(Lxx), Workstation Ada(...      3
# AD103     [GeForce 40, GeForce 40 Mobile, Workstation Ad...      4
# AD104     [GeForce 40, GeForce 40 Mobile, Server Ada(Lxx...      5
# AD106        [GeForce 40, GeForce 40 Mobile, Ada-MW(x000A)]      3
# ...                                                     ...    ...
# Vega 10   [Radeon Instinct(MIx), Radeon Pro Vega(Vega Se...      7
# Vega 20   [Radeon Instinct(MIx), Radeon Pro Vega(Vega II...      4
# Venus     [FirePro Mobile(Mx100), Solar System(HD 8800M)...      6
# Wani      [GCN 3.0 IGP(Carrizo Mobile), GCN 3.0 IGP(Bris...      2
# Whistler  [FirePro Mobile(Mx900), Embedded(6000), Vancou...      6
#
# [303 rows x 2 columns]

# %%
df = df[df['architecture'].isna() == False] # drop all null architectures

# %%
disp = get_association_df(df, 'foundry', 'gpu_name')
df = df[~((df['foundry']=='UMC') & (df['gpu_name']=='M9'))] # remove the older M9 chip variant
df = df[~((df['foundry']=='SGS Microelettronica') & (df['gpu_name']=='Mach64 GT-B'))] # remove SGS Microelettronica foundry chip version
disp
# Out:
#                                  foundry  count
# gpu_name
# M9                           [TSMC, UMC]      2
# Mach64 GT-B  [SGS Microelettronica, UMC]      2

# %%
disp = get_association_df(df, 'foundry', 'gpu_name')
disp
# Out:
# Empty DataFrame
# Columns: [foundry, count]
# Index: []

# %%
disp = get_association_df(df, 'transistor_density_k_mm2', 'gpu_name')
df = df[~((df['foundry']==16900.0) & (df['gpu_name']=='GM20B'))] # remove the older M9 chip variant
disp
# Out:
#          transistor_density_k_mm2  count
# gpu_name
# GM20B          [16900.0, 20000.0]      2

# %%
disp = get_association_df(df, 'die_size_mm2', 'gpu_name')
df = df[~((df['die_size_mm2']==118.0) & (df['gpu_name']=='GM20B'))] # remove the older M9 chip variant
disp
# Out:
#             die_size_mm2  count
# gpu_name
# GM20B     [118.0, 100.0]      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3087 entries, 0 to 3205
# Data columns (total 54 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   manufacturer                      3087 non-null   object
#  1   name                              3087 non-null   object
#  2   gpu_name                          3087 non-null   object
#  3   generation                        3087 non-null   object
#  4   base_clock_mhz                    3087 non-null   float64
#  5   boost_clock_mhz                   3087 non-null   float64
#  6   architecture                      3087 non-null   object
#  7   foundry                           2962 non-null   object
#  8   process_size_nm                   3083 non-null   float64
#  9   transistor_count_m                2846 non-null   float64
#  10  transistor_density_k_mm2          2817 non-null   float64
#  11  die_size_mm2                      2882 non-null   float64
#  12  chip_package                      1858 non-null   object
#  13  release_date                      3025 non-null   object
#  14  bus_interface                     3047 non-null   object
#  15  memory_clock_mhz                  2621 non-null   float64
#  16  memory_size_gb                    3087 non-null   float64
#  17  memory_bus_bits                   2621 non-null   float64
#  18  memory_bandwidth_gb_s             2621 non-null   float64
#  19  memory_type                       3087 non-null   object
#  20  shading_units                     3087 non-null   int64
#  21  texture_mapping_units             3087 non-null   int64
#  22  render_output_processors          3087 non-null   int64
#  23  streaming_multiprocessors         3087 non-null   int64
#  24  tensor_cores                      3087 non-null   int64
#  25  ray_tracing_cores                 3087 non-null   int64
#  26  l1_cache_kb                       3087 non-null   float64
#  27  l2_cache_mb                       3087 non-null   float64
#  28  thermal_design_power_w            2375 non-null   float64
#  29  board_length_mm                   1047 non-null   float64
#  30  board_width_mm                    546 non-null    float64
#  31  board_slot_width                  2745 non-null   object
#  32  suggested_psu_w                   1623 non-null   float64
#  33  power_connectors                  758 non-null    object
#  34  display_connectors                1482 non-null   object
#  35  directx_major_version             2992 non-null   float64
#  36  directx_minor_version             2992 non-null   float64
#  37  opengl_major_version              2978 non-null   float64
#  38  opengl_minor_version              2978 non-null   float64
#  39  vulkan_major_version              1450 non-null   float64
#  40  vulkan_minor_version              1450 non-null   float64
#  41  opencl_major_version              2150 non-null   float64
#  42  opencl_minor_version              2150 non-null   float64
#  43  cuda_major_version                1051 non-null   float64
#  44  cuda_minor_version                1051 non-null   float64
#  45  shader_model_major_version        2509 non-null   float64
#  46  shader_model_minor_version        2509 non-null   float64
#  47  pixel_rate_gpixel_s               3087 non-null   float64
#  48  texture_rate_gtexel_s             3087 non-null   float64
#  49  half_float_performance_gflop_s    942 non-null    float64
#  50  single_float_performance_gflop_s  2285 non-null   float64
#  51  double_float_performance_gflop_s  1679 non-null   float64
#  52  tpu_id                            3087 non-null   object
#  53  tpu_url                           3087 non-null   object
# dtypes: float64(33), int64(6), object(15)
# memory usage: 1.3+ MB

# %%
df.to_csv('../Source/Clean/2025-08.csv', index=False)
