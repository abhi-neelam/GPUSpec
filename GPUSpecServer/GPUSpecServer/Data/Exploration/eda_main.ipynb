# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("../Source/Raw/2025-08.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3206 entries, 0 to 3205
# Data columns (total 54 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   manufacturer                      3206 non-null   object
#  1   name                              3206 non-null   object
#  2   gpu_name                          3206 non-null   object
#  3   generation                        3206 non-null   object
#  4   base_clock_mhz                    3206 non-null   float64
#  5   boost_clock_mhz                   3206 non-null   float64
#  6   architecture                      3178 non-null   object
#  7   foundry                           3081 non-null   object
#  8   process_size_nm                   3202 non-null   float64
#  9   transistor_count_m                2963 non-null   float64
#  10  transistor_density_k_mm2          2928 non-null   float64
#  11  die_size_mm2                      2994 non-null   float64
#  12  chip_package                      1927 non-null   object
#  13  release_date                      3140 non-null   object
#  14  bus_interface                     3157 non-null   object
#  15  memory_clock_mhz                  2740 non-null   float64
#  16  memory_size_gb                    3206 non-null   float64
#  17  memory_bus_bits                   2740 non-null   float64
#  18  memory_bandwidth_gb_s             2740 non-null   float64
#  19  memory_type                       3206 non-null   object
#  20  shading_units                     3206 non-null   int64
#  21  texture_mapping_units             3206 non-null   int64
#  22  render_output_processors          3206 non-null   int64
#  23  streaming_multiprocessors         3206 non-null   int64
#  24  tensor_cores                      3206 non-null   int64
#  25  ray_tracing_cores                 3206 non-null   int64
#  26  l1_cache_kb                       3206 non-null   float64
#  27  l2_cache_mb                       3206 non-null   float64
#  28  thermal_design_power_w            2486 non-null   float64
#  29  board_length_mm                   1118 non-null   float64
#  30  board_width_mm                    583 non-null    float64
#  31  board_slot_width                  2841 non-null   object
#  32  suggested_psu_w                   1705 non-null   float64
#  33  power_connectors                  782 non-null    object
#  34  display_connectors                1564 non-null   object
#  35  directx_major_version             3103 non-null   float64
#  36  directx_minor_version             3103 non-null   float64
#  37  opengl_major_version              3082 non-null   float64
#  38  opengl_minor_version              3082 non-null   float64
#  39  vulkan_major_version              1453 non-null   float64
#  40  vulkan_minor_version              1453 non-null   float64
#  41  opencl_major_version              2233 non-null   float64
#  42  opencl_minor_version              2233 non-null   float64
#  43  cuda_major_version                1077 non-null   float64
#  44  cuda_minor_version                1077 non-null   float64
#  45  shader_model_major_version        2594 non-null   float64
#  46  shader_model_minor_version        2594 non-null   float64
#  47  pixel_rate_gpixel_s               3206 non-null   float64
#  48  texture_rate_gtexel_s             3206 non-null   float64
#  49  half_float_performance_gflop_s    945 non-null    float64
#  50  single_float_performance_gflop_s  2369 non-null   float64
#  51  double_float_performance_gflop_s  1696 non-null   float64
#  52  tpu_id                            3206 non-null   object
#  53  tpu_url                           3206 non-null   object
# dtypes: float64(33), int64(6), object(15)
# memory usage: 1.3+ MB

# %%
nan_columns = df.columns[df.isnull().any()]

print("Columns with NaN values:")
print(nan_columns)
# Out:
# Columns with NaN values:
# Index(['architecture', 'foundry', 'process_size_nm', 'transistor_count_m',
#        'transistor_density_k_mm2', 'die_size_mm2', 'chip_package',
#        'release_date', 'bus_interface', 'memory_clock_mhz', 'memory_bus_bits',
#        'memory_bandwidth_gb_s', 'thermal_design_power_w', 'board_length_mm',
#        'board_width_mm', 'board_slot_width', 'suggested_psu_w',
#        'power_connectors', 'display_connectors', 'directx_major_version',
#        'directx_minor_version', 'opengl_major_version', 'opengl_minor_version',
#        'vulkan_major_version', 'vulkan_minor_version', 'opencl_major_version',
#        'opencl_minor_version', 'cuda_major_version', 'cuda_minor_version',
#        'shader_model_major_version', 'shader_model_minor_version',
#        'half_float_performance_gflop_s', 'single_float_performance_gflop_s',
#        'double_float_performance_gflop_s'],
#       dtype='object')

# %%
def get_association_df(df, parent, child):
    options = df.groupby([child])[parent].unique()
    count = df.groupby([child])[parent].nunique()
    
    association_df = pd.DataFrame(data={f'{parent}':options, 'count':count})
    association_df = association_df[association_df['count']>1]
    return association_df

# %%
#df['release_date'] = pd.to_datetime(df['release_date'])
#df.sort_values(by='release_date', ascending=False, inplace=True)
#df.drop_duplicates(subset=['name'], inplace=True)
#df

# %%
disp = get_association_df(df, 'manufacturer', 'architecture')

df = df[~((df['manufacturer']=='AMD') & (df['architecture']=='TeraScale'))] # remove all AMD manufactured chips from terascale architecture
df = df[~((df['manufacturer']=='ATI') & (df['architecture']=='TeraScale 2'))] # remove all ATI manufactured chips from terascale 2 architecture
df = df[~((df['manufacturer']=='AMD') & (df['architecture']=='Ultra-Threaded SE'))] # remove all AMD manufactured chips from UT SE architecture

disp
# Out:
#                   manufacturer  count
# architecture
# TeraScale           [ATI, AMD]      2
# TeraScale 2         [AMD, ATI]      2
# Ultra-Threaded SE   [ATI, AMD]      2

# %%
get_association_df(df, 'architecture', 'generation')
# Out:
#                                                                     architecture  \
# generation
# All-In-One(Rx 200)                               [TeraScale 2, GCN 1.0, GCN 3.0]
# All-In-One(Rx 300)                                            [GCN 1.0, GCN 3.0]
# All-In-Wonder(2006 Edition)                            [R300, Ultra-Threaded SE]
# All-In-Wonder(7000)                                             [Rage 6, Rage 7]
# All-In-Wonder(9000)                                               [R300, Rage 7]
# All-In-Wonder(X)                                                    [R400, R300]
# Arctic Islands(RX 400)                                        [GCN 2.0, GCN 4.0]
# Console GPU(AMD)                                  [RDNA 3.0, RDNA 3.5, RDNA 2.0]
# Console GPU(Microsoft)           [Kelvin, TeraScale, GCN 1.0, GCN 2.0, RDNA 2.0]
# Console GPU(Nintendo)          [Rage 5, Ultra-Threaded SE, TeraScale 2, Maxwe...
# Console GPU(Sony)              [nan, Curie, PowerVR Series5XT, GCN 2.0, RDNA ...
# Data Center GPU(Arctic Sound)                 [Generation 12.5, Generation 12.7]
# Embedded(8000)                                       [GCN 1.0, GCN 2.0, GCN 3.0]
# FireGL(9000)                                                        [R300, R400]
# FireGL(Vx100)                                                       [R300, R400]
# FireGL(Vx200)                                          [R300, Ultra-Threaded SE]
# FireMV Multi-View(2000)             [R300, Rage 7, Ultra-Threaded SE, TeraScale]
# FirePro GCN(Wx100)                                   [GCN 1.0, GCN 2.0, GCN 3.0]
# FirePro Mobile(Mx000)                                     [TeraScale 2, GCN 1.0]
# FirePro Mobile(Mx100)                                         [GCN 1.0, GCN 2.0]
# FirePro Mobile(Wx100M)                               [GCN 1.0, GCN 2.0, GCN 3.0]
# FirePro Server(Sx100)                                         [GCN 2.0, GCN 3.0]
# FirePro Terascale(Vx900)                              [TeraScale 2, TeraScale 3]
# GMA Graphics-M(GMA 3000 IGP)                    [Generation 3.5, Generation 4.0]
# GRID(Mx)                                                  [Maxwell 2.0, Maxwell]
# GeForce 10                                               [Pascal, Volta, Kepler]
# GeForce 100M                                                  [Tesla, Tesla 2.0]
# GeForce 20 Mobile                                               [Turing, Ampere]
# GeForce 200                                                   [Tesla 2.0, Tesla]
# GeForce 200M                                                  [Tesla, Tesla 2.0]
# GeForce 300                                                   [Tesla 2.0, Tesla]
# GeForce 300M                                                  [Tesla, Tesla 2.0]
# GeForce 40                                                [Ada Lovelace, Ampere]
# GeForce 400                                        [Tesla 2.0, Fermi, Fermi 2.0]
# GeForce 400M                                       [Fermi, Tesla 2.0, Fermi 2.0]
# GeForce 500                                        [Fermi 2.0, Fermi, Tesla 2.0]
# GeForce 500M                                                  [Fermi, Fermi 2.0]
# GeForce 6 AGP(6200)                                             [Celsius, Curie]
# GeForce 600                               [Fermi 2.0, Fermi, Kepler, Kepler 2.0]
# GeForce 600M                                          [Fermi 2.0, Fermi, Kepler]
# GeForce 700                    [Kepler, Fermi 2.0, Kepler 2.0, Fermi, Maxwell...
# GeForce 700A                                     [Fermi 2.0, Kepler 2.0, Kepler]
# GeForce 700M                                     [Fermi 2.0, Kepler 2.0, Kepler]
# GeForce 8(8400)                                               [Tesla, Tesla 2.0]
# GeForce 800A                                    [Fermi 2.0, Kepler 2.0, Maxwell]
# GeForce 800M                            [Fermi 2.0, Kepler 2.0, Maxwell, Kepler]
# GeForce 9(9300)                                               [Tesla, Tesla 2.0]
# GeForce 9(9400)                                               [Tesla, Tesla 2.0]
# GeForce 900A                                               [Kepler 2.0, Maxwell]
# GeForce 900M                                  [Maxwell 2.0, Kepler 2.0, Maxwell]
# GeForce FX(5200)                                              [Celsius, Rankine]
# GeForce MX(1xx)                                                [Maxwell, Pascal]
# GeForce MX(5xx)                                                 [Turing, Ampere]
# GeForce PCX                                                   [Rankine, Celsius]
# GeForce4 Go                                                    [Celsius, Kelvin]
# Gem System Hybrid(Rx M200)                                    [GCN 3.0, GCN 1.0]
# Gem System Hybrid(Rx M300)                                    [GCN 1.0, GCN 3.0]
# Gem System Hybrid(Rx M400)                                    [GCN 1.0, GCN 3.0]
# Gem System(R5 M200)                                           [GCN 1.0, GCN 3.0]
# Gem System(R5 M300)                                           [GCN 3.0, GCN 1.0]
# Gem System(R5 M400)                                           [GCN 1.0, GCN 3.0]
# Gem System(R7 M200)                                           [GCN 3.0, GCN 1.0]
# Gem System(R7 M300)                                           [GCN 1.0, GCN 3.0]
# Gem System(R7 M400)                                           [GCN 3.0, GCN 1.0]
# Gem System(R9 M200)                                  [GCN 1.0, GCN 3.0, GCN 2.0]
# Gem System(R9 M300)                                  [GCN 1.0, GCN 2.0, GCN 3.0]
# Gem System(R9 M400)                                           [GCN 2.0, GCN 3.0]
# Graphics                                                  [i740, Generation 1.0]
# Graphics(IGP)                                             [i740, Generation 1.0]
# Graphics-M(IGP)                                 [Generation 1.0, Generation 2.0]
# ION                                                           [Tesla 2.0, Tesla]
# M1x(Mobility 9000)                                                  [R300, R400]
# M2x(Mobility X1)                                                    [R300, R400]
# M7x(Mobility HD 2000)                             [Ultra-Threaded SE, TeraScale]
# Mining GPUs                                      [Pascal, Volta, Ampere, Turing]
# Mobility FireGL                                                   [Rage 7, R300]
# Mobility FireGL(V5xxx)                      [R400, Ultra-Threaded SE, TeraScale]
# NVS                                      [Tesla 2.0, Kepler, Fermi 2.0, Maxwell]
# NVS Mobile                                                        [Curie, Tesla]
# NVS Mobile(x200M)                                             [Fermi 2.0, Fermi]
# Pirate Islands(R5 300)                                    [TeraScale 2, GCN 1.0]
# Pirate Islands(R7 300)                                        [GCN 1.0, GCN 2.0]
# Pirate Islands(R9 300)                               [GCN 2.0, GCN 1.0, GCN 3.0]
# Polaris Mobile(M500)                                 [GCN 1.0, GCN 3.0, GCN 4.0]
# Polaris Mobile(M500X)                                         [GCN 3.0, GCN 4.0]
# Polaris Mobile(M600)                                 [GCN 1.0, GCN 3.0, GCN 4.0]
# Polaris(RX 500)                                               [GCN 4.0, GCN 1.0]
# Polaris(RX 600)                                               [GCN 3.0, GCN 4.0]
# Quadro FX Go                                                    [Rankine, Curie]
# Quadro FX Mobile(x800M)                                       [Tesla, Tesla 2.0]
# Quadro FX Rankine(x000)                                         [Rankine, Curie]
# Quadro FX Tesla(x600)                                             [Curie, Tesla]
# Quadro FX Tesla(x800)                                         [Tesla 2.0, Tesla]
# Quadro Fermi(x000)                                 [Fermi, Tesla 2.0, Fermi 2.0]
# Quadro Fermi-M(x000M)                                         [Fermi, Fermi 2.0]
# Quadro Kepler(Kx200)                                           [Maxwell, Kepler]
# Quadro Kepler-M(Kx100M)                                     [Kepler, Kepler 2.0]
# Quadro Maxwell-M(Mx000M)                                  [Maxwell, Maxwell 2.0]
# Quadro Maxwell-M(Mx200)                                   [Maxwell, Maxwell 2.0]
# Quadro NVS                                      [Rankine, Celsius, Curie, Tesla]
# Quadro2 Celcius                                                [Celsius, Kelvin]
# Quadro4 Celcius(x00)                                           [Celsius, Kelvin]
# Quadro4 Celcius(x50)                                           [Celsius, Kelvin]
# Quadro4 Celcius(x80)                                           [Celsius, Kelvin]
# Quadro4 Go                                                     [Celsius, Kelvin]
# Radeon IGP(2000)                                               [R400, TeraScale]
# Radeon Instinct(MIx)           [GCN 4.0, GCN 3.0, GCN 5.0, GCN 5.1, CDNA 1.0,...
# Radeon Pro GCN                                                [GCN 3.0, GCN 4.0]
# Radeon Pro Mac(Vega Series)                                   [GCN 5.0, GCN 5.1]
# Radeon Pro Polaris(WX x100)                                   [GCN 4.0, GCN 5.0]
# Radeon Pro Polaris(WX x200)                                   [GCN 5.0, GCN 4.0]
# Radeon R300(X550)                                                   [R300, R400]
# Rage 2                                                            [Mach, Rage 2]
# Rage 3                                                            [Rage 3, Mach]
# Rage Mobility                                                     [Mach, Rage 4]
# Sea Islands(HD 8500)                                      [TeraScale 2, GCN 1.0]
# Sea Islands(HD 8700)                                          [GCN 1.0, GCN 2.0]
# Server Blackwell(Bxx)                                 [Blackwell, Blackwell 2.0]
# Solar System(HD 8900M)                                        [GCN 2.0, GCN 1.0]
# Southern Islands(HD 7700)                        [GCN 1.0, TeraScale 2, GCN 2.0]
# Tesla Fermi(x20xx)                                            [Fermi, Fermi 2.0]
# Tesla Kepler(Kxx)                                           [Kepler, Kepler 2.0]
# Tesla Maxwell(Mxx)                                        [Maxwell 2.0, Maxwell]
# Volcanic Islands(R5 200)                                  [TeraScale 2, GCN 1.0]
# Volcanic Islands(R7 200)                                      [GCN 1.0, GCN 2.0]
# Volcanic Islands(R9 200)                             [GCN 1.0, GCN 3.0, GCN 2.0]
#
#                                count
# generation
# All-In-One(Rx 200)                 3
# All-In-One(Rx 300)                 2
# All-In-Wonder(2006 Edition)        2
# All-In-Wonder(7000)                2
# All-In-Wonder(9000)                2
# All-In-Wonder(X)                   2
# Arctic Islands(RX 400)             2
# Console GPU(AMD)                   3
# Console GPU(Microsoft)             5
# Console GPU(Nintendo)              5
# Console GPU(Sony)                  4
# Data Center GPU(Arctic Sound)      2
# Embedded(8000)                     3
# FireGL(9000)                       2
# FireGL(Vx100)                      2
# FireGL(Vx200)                      2
# FireMV Multi-View(2000)            4
# FirePro GCN(Wx100)                 3
# FirePro Mobile(Mx000)              2
# FirePro Mobile(Mx100)              2
# FirePro Mobile(Wx100M)             3
# FirePro Server(Sx100)              2
# FirePro Terascale(Vx900)           2
# GMA Graphics-M(GMA 3000 IGP)       2
# GRID(Mx)                           2
# GeForce 10                         3
# GeForce 100M                       2
# GeForce 20 Mobile                  2
# GeForce 200                        2
# GeForce 200M                       2
# GeForce 300                        2
# GeForce 300M                       2
# GeForce 40                         2
# GeForce 400                        3
# GeForce 400M                       3
# GeForce 500                        3
# GeForce 500M                       2
# GeForce 6 AGP(6200)                2
# GeForce 600                        4
# GeForce 600M                       3
# GeForce 700                        6
# GeForce 700A                       3
# GeForce 700M                       3
# GeForce 8(8400)                    2
# GeForce 800A                       3
# GeForce 800M                       4
# GeForce 9(9300)                    2
# GeForce 9(9400)                    2
# GeForce 900A                       2
# GeForce 900M                       3
# GeForce FX(5200)                   2
# GeForce MX(1xx)                    2
# GeForce MX(5xx)                    2
# GeForce PCX                        2
# GeForce4 Go                        2
# Gem System Hybrid(Rx M200)         2
# Gem System Hybrid(Rx M300)         2
# Gem System Hybrid(Rx M400)         2
# Gem System(R5 M200)                2
# Gem System(R5 M300)                2
# Gem System(R5 M400)                2
# Gem System(R7 M200)                2
# Gem System(R7 M300)                2
# Gem System(R7 M400)                2
# Gem System(R9 M200)                3
# Gem System(R9 M300)                3
# Gem System(R9 M400)                2
# Graphics                           2
# Graphics(IGP)                      2
# Graphics-M(IGP)                    2
# ION                                2
# M1x(Mobility 9000)                 2
# M2x(Mobility X1)                   2
# M7x(Mobility HD 2000)              2
# Mining GPUs                        4
# Mobility FireGL                    2
# Mobility FireGL(V5xxx)             3
# NVS                                4
# NVS Mobile                         2
# NVS Mobile(x200M)                  2
# Pirate Islands(R5 300)             2
# Pirate Islands(R7 300)             2
# Pirate Islands(R9 300)             3
# Polaris Mobile(M500)               3
# Polaris Mobile(M500X)              2
# Polaris Mobile(M600)               3
# Polaris(RX 500)                    2
# Polaris(RX 600)                    2
# Quadro FX Go                       2
# Quadro FX Mobile(x800M)            2
# Quadro FX Rankine(x000)            2
# Quadro FX Tesla(x600)              2
# Quadro FX Tesla(x800)              2
# Quadro Fermi(x000)                 3
# Quadro Fermi-M(x000M)              2
# Quadro Kepler(Kx200)               2
# Quadro Kepler-M(Kx100M)            2
# Quadro Maxwell-M(Mx000M)           2
# Quadro Maxwell-M(Mx200)            2
# Quadro NVS                         4
# Quadro2 Celcius                    2
# Quadro4 Celcius(x00)               2
# Quadro4 Celcius(x50)               2
# Quadro4 Celcius(x80)               2
# Quadro4 Go                         2
# Radeon IGP(2000)                   2
# Radeon Instinct(MIx)               8
# Radeon Pro GCN                     2
# Radeon Pro Mac(Vega Series)        2
# Radeon Pro Polaris(WX x100)        2
# Radeon Pro Polaris(WX x200)        2
# Radeon R300(X550)                  2
# Rage 2                             2
# Rage 3                             2
# Rage Mobility                      2
# Sea Islands(HD 8500)               2
# Sea Islands(HD 8700)               2
# Server Blackwell(Bxx)              2
# Solar System(HD 8900M)             2
# Southern Islands(HD 7700)          3
# Tesla Fermi(x20xx)                 2
# Tesla Kepler(Kxx)                  2
# Tesla Maxwell(Mxx)                 2
# Volcanic Islands(R5 200)           2
# Volcanic Islands(R7 200)           2
# Volcanic Islands(R9 200)           3

# %%
disp = get_association_df(df, 'architecture', 'gpu_name')

df[df['gpu_name']=='Condor']
df = df[~((df['gpu_name']=='Condor') & (df['architecture']=='G400'))] # remove all Condor chip products from G400 architecture
disp
# Out:
#           architecture  count
# gpu_name
# Condor    [G400, G500]      2

# %% [markdown]
# **Graphics**

# %%
disp = get_association_df(df, 'directx_major_version', 'gpu_name')
df = df[~((df['directx_major_version']==10.0) & (df['gpu_name']=='GT215'))] # remove the older GT215 chip product
disp
# Out:
#          directx_major_version  count
# gpu_name
# GT215             [10.0, 11.0]      2

# %%
disp = get_association_df(df, 'cuda_minor_version', 'gpu_name')
df = df[~((df['cuda_minor_version']==1.0) & (df['gpu_name']=='G92B'))] # remove the older G92B chip product
disp
# Out:
#          cuda_minor_version  count
# gpu_name
# G92B             [1.0, 3.0]      2

# %%
disp = get_association_df(df, 'generation', 'gpu_name')
disp
# Out:
#                                                           generation  count
# gpu_name
# 18800-1                                                   [EGA, VGA]      2
# AD102              [GeForce 40, Server Ada(Lxx), Workstation Ada(...      3
# AD103              [GeForce 40, GeForce 40 Mobile, Workstation Ad...      4
# AD104              [GeForce 40, GeForce 40 Mobile, Server Ada(Lxx...      5
# AD106                 [GeForce 40, GeForce 40 Mobile, Ada-MW(x000A)]      3
# AD107              [GeForce 40, GeForce 40 Mobile, Ada-MW(x000A),...      4
# Alder Lake         [HD Graphics(Alder Lake), HD Graphics-M(Alder ...      2
# Amethyst           [Gem System(R9 M200), FirePro Mobile(Wx100M), ...      6
# Auburn                                     [Graphics, Graphics(IGP)]      2
# Baffin             [Embedded(9000), Radeon Pro Mac(400 Series), R...     10
# Banks              [Arctic Islands(R5 400), Polaris Mobile(M500),...      4
# Barts              [Northern Islands(HD 6800), Northern Islands(H...      3
# Bearlake           [GMA Graphics-M(GMA 3100 IGP), GMA Graphics(GM...      3
# Blackcomb               [FirePro Mobile(Mx900), Vancouver(HD 6900M)]      2
# Bonaire            [Southern Islands(HD 7700), Sea Islands(HD 870...      5
# Broadwater         [GMA Graphics(GMA 3000 IGP), GMA Graphics-M(GM...      3
# Broadwell GT2      [HD Graphics-M(Broadwell), HD Graphics-W(Broad...      2
# Broadwell GT3e     [HD Graphics(Broadwell), HD Graphics-M(Broadwe...      3
# C51                [Quadro NVS IGP, GeForce 6 IGP, GeForce Go 6 I...      3
# C61                                   [GeForce 6 IGP, GeForce 7 IGP]      2
# C67                           [GeForce 7M IGP(7000M), GeForce 7 IGP]      2
# C77                   [GeForce 8M IGP(8000M), GeForce 9M IGP(9000M)]      2
# C78                                   [GeForce 8 IGP, GeForce 9 IGP]      2
# C79                [GeForce 8M IGP(8000M), GeForce 9M IGP(9000M),...      7
# Caicos             [Embedded(6000), Northern Islands(HD 6400), Al...      9
# Cape Verde         [FirePro GCN(Wx000), Southern Islands(HD 7700)...      8
# Capsaicin          [Pirate Islands(R9 300), FirePro Server(Sx300)...      3
# Cayman             [Northern Islands(HD 6900), FirePro Terascale(...      2
# Cedar              [FirePro Multi-View(2200), Northern Islands(HD...      7
# Chelsea                    [FirePro Mobile(Mx000), London(HD 7700M)]      2
# Coffee Lake GT1    [HD Graphics(Coffee Lake), HD Graphics-M(Coffe...      2
# Coffee Lake GT2    [HD Graphics(Coffee Lake), HD Graphics-M(Coffe...      4
# Comet Lake GT1     [HD Graphics-M(Comet Lake), HD Graphics(Comet ...      2
# Comet Lake GT2     [HD Graphics-M(Comet Lake), HD Graphics(Comet ...      4
# Curacao             [Sea Islands(HD 8800), Volcanic Islands(R7 200)]      2
# Cypress                      [FireStream, Northern Islands(HD 6800)]      2
# DG1                                      [H3C Graphics, Xe Graphics]      2
# DG2-128            [Alchemist(Arc 3), Alchemist(Arc 3 Mobile), Al...      5
# DG2-256            [Alchemist(Arc 5 Mobile), Alchemist(Pro Series...      3
# DG2-512            [Alchemist(Arc 5 Mobile), Alchemist(Arc 7 Mobi...      5
# Devastator         [TeraScale 3 IGP(Trinity Mobile), TeraScale 3 ...      4
# Devastator Lite    [TeraScale 3 IGP(Trinity Mobile), TeraScale 3 ...      4
# Eaglelake          [GMA Graphics(GMA 4500 IGP), GMA Graphics-M(GM...      2
# Ellesmere          [Embedded(9000), Radeon Instinct(MIx), Radeon ...     12
# Emerald            [FirePro Mobile(Mx100), FirePro Mobile(Wx100M)...      3
# Exo                [Pirate Islands(R5 300), All-In-One(Rx 300), G...      4
# Fiji               [Pirate Islands(R9 300), Radeon Instinct(MIx),...      3
# G70                [GeForce 7 PCIe(7800), GeForce Go 7(Go 7000), ...      4
# G71                [Quadro FX Mobile(x500M), GeForce 7 AGP(7600),...      8
# G72                [GeForce 7 PCIe(7200), GeForce 7 PCIe(7300), G...      7
# G72B                             [GeForce Go 7(Go 7000), NVS Mobile]      2
# G73                [GeForce 7 PCIe(7300), GeForce 7 PCIe(7600), G...      6
# G73B               [GeForce 7 PCIe(7300), GeForce 7 AGP(7300), Ge...      5
# G80                [GeForce 8(8800), Quadro FX Tesla(x600), Tesla...      3
# G84                [GeForce 8(8600), GeForce 8M(8000M), Quadro FX...      8
# G86                             [GeForce 8M(8000M), GeForce 8(8500)]      2
# G86S               [GeForce 8(8300), GeForce 8(8400), GeForce 8M(...      8
# G92                [GeForce 8(8800), GeForce 8M(8000M), GeForce 9...     11
# G94                [GeForce 9(9600), GeForce 9M(9700M), GeForce 9...      7
# G94B                     [GeForce 9(9600), GeForce 100, GeForce 200]      3
# G96                [GeForce 9(9500), GeForce 9M(9500M), GeForce 9...      5
# G96C               [GeForce 9(9400), GeForce 9(9500), GeForce 9M(...      9
# G98                             [GeForce 9M(9000M), GeForce 9(9300)]      2
# G98S               [GeForce 8(8400), GeForce 9M(9000M), GeForce 9...      8
# GA100              [Server Ampere(Axx), DRIVE(Axx), GRID(Ax), Min...      4
# GA102              [Server Ampere(Axx), GeForce 30, Workstation A...      4
# GA103              [GeForce 30, GeForce 30 Mobile, Ampere-MW(Ax000)]      3
# GA104              [GeForce 30, Mining GPUs, GeForce 30 Mobile, A...      5
# GA106              [GeForce 30 Mobile, GeForce 30, Workstation Am...      3
# GA107              [Server Ampere(Axx), Workstation Ampere(Ax000)...      7
# GA107S                           [GeForce MX(5xx), Ampere-MW(Ax000)]      2
# GA10B                         [Tegra(Ampere), Console GPU(Nintendo)]      2
# GB202              [GeForce 50, Blackwell PRO W(x000), Server Bla...      3
# GB203              [GeForce 50, GeForce 50 Mobile, Blackwell PRO ...      3
# GB205                                [GeForce 50, GeForce 50 Mobile]      2
# GB206              [GeForce 50, GeForce 50 Mobile, Blackwell PRO ...      3
# GB207                                [GeForce 50, GeForce 50 Mobile]      2
# GF100              [GeForce 400, GeForce 400M, Quadro Fermi(x000)...      5
# GF104              [GeForce 400, GeForce 400M, Quadro Fermi-M(x00...      3
# GF106              [GeForce 400, GeForce 400M, Quadro Fermi(x000)...      5
# GF108              [GeForce 400M, GeForce 400, Quadro Fermi(x000)...     11
# GF110              [GeForce 500, Quadro Fermi-M(x000M), Quadro Pl...      5
# GF114              [GeForce 400, GeForce 500, GeForce 500M, GeFor...      5
# GF116              [GeForce 500, GeForce 400, GeForce 500M, GeFor...      4
# GF116S                                  [GeForce 500M, GeForce 600M]      2
# GF117              [GeForce 600M, NVS Mobile(x200M), GeForce 700M...      6
# GF117B                                  [GeForce 600M, GeForce 800M]      2
# GF119                                   [GeForce 600M, GeForce 500M]      2
# GF119S             [GeForce 400M, GeForce 500, GeForce 600A, NVS ...      9
# GK104              [GeForce 600, GeForce 600M, Quadro Kepler-M(Kx...     12
# GK106              [GeForce 600, GeForce 700M, Quadro Kepler(Kx00...      4
# GK106S             [GeForce 600, GeForce 700M, Quadro Kepler-M(Kx...      4
# GK107              [GeForce 600, GeForce 600M, NVS, Quadro Kepler...     15
# GK110              [Tesla Kepler(Kxx), GeForce 700, Quadro Kepler...      3
# GK110B             [GeForce 700, Quadro Kepler(Kx000), Tesla Kepl...      4
# GK180                               [GeForce 700, Tesla Kepler(Kxx)]      2
# GK208              [GeForce 700M, GeForce 600, GeForce 700A, Quad...      7
# GK208B                     [GeForce 700, GeForce 900M, GeForce 900A]      3
# GM107              [GeForce 700, GeForce 800A, GeForce 800M, Quad...     12
# GM108              [GeForce 800A, GeForce 800M, GeForce 900A, GeF...      5
# GM108S             [GeForce 800M, GeForce 900M, GeForce 900A, Qua...      6
# GM200              [GeForce 900, Quadro Maxwell(Mx000), Tesla Max...      3
# GM204              [GeForce 900, GeForce 900M, GRID(Mx), Quadro M...      6
# GM206              [GeForce 700, GeForce 900, Tesla Maxwell(Mxx),...      5
# GM206S                                   [GeForce 900, GeForce 900M]      2
# GM20B                        [Tegra(Maxwell), Console GPU(Nintendo)]      2
# GP100                      [Quadro Pascal(Px000), Tesla Pascal(Pxx)]      2
# GP102              [Quadro Pascal(Px000), Tesla Pascal(Pxx), GeFo...      4
# GP104              [GeForce 10, Quadro Pascal(Px000), Tesla Pasca...      6
# GP106              [GeForce 10, GeForce 10 Mobile, Mining GPUs, Q...      6
# GP107              [GeForce 10, GeForce 10 Mobile, Quadro Pascal(...      7
# GP108              [GeForce 10, GeForce MX(1xx), Quadro Pascal-M(...      5
# GP108B                            [GeForce MX(2xx), GeForce MX(3xx)]      2
# GT200B             [GeForce 200, Quadro FX Tesla(x800), Tesla(x10...      3
# GT216              [GeForce 200, GeForce 200M, GeForce 300, GeFor...      9
# GT218                                   [GeForce 300M, GeForce 400M]      2
# GT218S             [GeForce 8(8400), ION, GeForce 200, GeForce 30...     15
# GV100              [Tesla Volta(Vxx), GeForce 10, Quadro Volta(Vx...      4
# Haswell GT1           [HD Graphics(Haswell), HD Graphics-M(Haswell)]      2
# Haswell GT2        [HD Graphics-M(Haswell), HD Graphics(Haswell),...      3
# Haswell GT3e          [HD Graphics(Haswell), HD Graphics-M(Haswell)]      2
# Hawaii             [FirePro Server(Sx100), FirePro GCN(Wx100), Vo...      3
# Hawk Point         [Navi III IGP(Hawx Point Mobile), Console GPU(...      2
# Heathrow                   [FirePro Mobile(Mx000), London(HD 7800M)]      2
# Ironlake            [HD Graphics(Westmere), HD Graphics-M(Westmere)]      2
# Ivy Bridge GT1     [HD Graphics(Ivy Bridge), HD Graphics-M(Ivy Br...      2
# Ivy Bridge GT2     [HD Graphics(Ivy Bridge), HD Graphics-M(Ivy Br...      3
# Jet                [All-In-One(Rx 200), Gem System(R5 M200), Gem ...      8
# Kaby Lake GT1      [HD Graphics(Kaby Lake), HD Graphics-M(Kaby La...      2
# Kaby Lake GT2      [HD Graphics-M(Kaby Lake), HD Graphics(Kaby La...      4
# Kalindi            [GCN 2.0 IGP(Temash Mobile), GCN 2.0 IGP(Kabin...      3
# Knights Corner                [Knights Corner(x100), Knights Corner]      2
# Lakeport           [GMA Graphics(GMA 950 IGP), GMA Graphics-M(GMA...      3
# Lexa               [Polaris(RX 500), Embedded(9000), Radeon Pro P...      7
# Litho                     [Gem System(R7 M300), Gem System(R7 M400)]      2
# Loveland           [TeraScale 2 IGP(Palm Mobile), TeraScale 2 IGP...      3
# M10                            [Mobility FireGL, M1x(Mobility 9000)]      2
# M11                            [Mobility FireGL, M1x(Mobility 9000)]      2
# M22                       [Mobility FireGL(V3xxx), M2x(Mobility X1)]      2
# M24                       [Mobility FireGL(V3xxx), M2x(Mobility X1)]      2
# M26                       [Mobility FireGL(V5xxx), M2x(Mobility X1)]      2
# M3                           [Rage Mobility(128), Rage Mobility(Mx)]      2
# M4                           [Rage Mobility(128), Rage Mobility(Mx)]      2
# M56                       [Mobility FireGL(V5xxx), M5x(Mobility X1)]      2
# M64                             [M6x(Mobility X1), M6x(Mobility X2)]      2
# M66                [M6x(Mobility X1), Mobility FireGL(V5xxx), M6x...      3
# M7                              [Mobility FireGL, M7(Mobility 7500)]      2
# M71                        [M7x(Mobility HD 2000), M7x(Mobility X2)]      2
# M76                  [Mobility FireGL(V5xxx), M7x(Mobility HD 2000)]      2
# M86                  [Mobility FireGL(V5xxx), M8x(Mobility HD 3600)]      2
# M9                              [Mobility FireGL, M9(Mobility 9000)]      2
# M92                [M9x(Mobility HD 4300), M9x(Mobility HD 4500),...      4
# M93                [M9x(Mobility HD 4300), M9x(Mobility HD 4500),...      3
# M96                [FirePro Mobility(M5xxx), M9x(Mobility HD 4600...      5
# M97                 [FirePro Mobility(M7xxx), M9x(Mobility HD 4800)]      2
# Mach64 GT-B                         [Rage 2, All-In-Wonder(3D Rage)]      2
# Mach64 LT                                    [Rage Mobility, Rage 3]      2
# Malta              [Southern Islands(HD 7900), Sea Islands(HD 8900)]      2
# Mars               [FirePro Mobile(Mx100), All-In-One(HD 8000), S...      7
# Meso               [Gem System(R5 M300), All-In-One(Rx 300), Gem ...      8
# Montara            [Extreme Graphics 2(Mobile IGP), Graphics-M(IGP)]      2
# NV10                                   [GeForce 256, Quadro Celsius]      2
# NV11                                [GeForce 2 MX, GeForce 2 MX PCI]      2
# NV11B              [GeForce2 Go, Quadro2 Celcius, GeForce 2 MX, G...      5
# NV15                                    [GeForce 2, Quadro2 Celcius]      2
# NV17               [GeForce4 Go, GeForce 4 MX, Quadro4 Go, Quadro...      6
# NV18               [GeForce4 Go, GeForce 4 MX, Quadro4 Celcius(x8...      4
# NV18C              [GeForce 6 AGP(6200), GeForce FX(5200), GeForc...      5
# NV20                                    [GeForce 3, Quadro2 Celcius]      2
# NV25               [GeForce 4 Ti, Quadro4 Celcius(x00), Quadro4 C...      3
# NV28               [GeForce4 Go, GeForce 4 Ti, Quadro4 Celcius(x8...      4
# NV30                     [GeForce FX(5800), Quadro FX Rankine(x000)]      2
# NV31               [GeForce FX(5600), GeForce FX Go 5(Go 5000), Q...      3
# NV34               [GeForce FX(5100), GeForce FX(5200), GeForce F...      5
# NV34B              [GeForce FX(5200), GeForce FX Go 5(Go 5000), Q...      4
# NV35               [GeForce FX(5900), GeForce PCX, Quadro FX Rank...      3
# NV36               [GeForce FX(5700), Quadro FX Go, GeForce FX Go...      3
# NV36B                    [GeForce FX(5700), Quadro FX Rankine(x100)]      2
# NV37               [GeForce PCX, Quadro FX Rankine(x300), Quadro ...      3
# NV38               [GeForce FX(5900), GeForce PCX, Quadro FX Rank...      3
# NV40                  [GeForce 6 AGP(6800), Quadro FX Rankine(x000)]      2
# NV41               [GeForce 6 PCIe(6800), GeForce Go 6(Go 6000), ...      5
# NV43               [GeForce 6 PCIe(6200), GeForce 6 PCI(6200), Ge...     10
# NV44               [GeForce 6 AGP(6200), GeForce 6 PCIe(6200), Ge...      6
# NV44B              [GeForce 6 AGP(6200), GeForce 7 PCIe(7100), Ge...      3
# NV45                   [GeForce 6 PCIe(6800), Quadro FX Curie(x400)]      2
# Navi 10            [Radeon Pro Navi(Navi Series), Radeon Pro Mac(...      4
# Navi 12            [Radeon Pro Mac(Navi Mobile), Radeon Pro Navi(...      2
# Navi 14            [Radeon Pro Mac(Navi Mobile), Radeon Pro Mobil...      6
# Navi 21            [Navi II(RX 6000), Radeon Pro Navi(Navi II Ser...      3
# Navi 22                    [Navi II(RX 6000), Navi Mobile(RX 6000M)]      2
# Navi 23            [Radeon Pro Navi(Navi II Series), Radeon Pro M...      5
# Navi 24            [Radeon Pro Navi(Navi II Series), Radeon Pro M...      4
# Navi 31            [Navi III(RX 7000), Radeon Pro Navi(Navi III S...      3
# Navi 32            [Radeon Pro Navi(Navi III Series), Navi III(RX...      3
# Navi 33            [Radeon Pro Navi(Navi III Series), Navi III(RX...      3
# Navi 48            [Radeon Pro Navi(Navi IV Series), Navi IV(RX 9...      2
# Neptune                [Solar System(HD 8900M), Gem System(R9 M200)]      2
# Oland              [Sea Islands(HD 8500), Sea Islands(HD 8600), V...     10
# Onega                     [All-In-One(HD 6000), All-In-One(HD 7000)]      2
# Opal               [FirePro Mobile(Mx100), All-In-One(Rx 200), Ge...      7
# Park               [Northern Islands(HD 6200), Northern Islands(H...      2
# Phoenix            [Navi III IGP(Phoenix Mobile), Console GPU(AMD...      3
# Picasso-M              [Vega IGP(Picasso Mobile), Vega IGP(Picasso)]      2
# Pineview           [GMA Graphics(GMA 3100 IGP), GMA Graphics-M(GM...      2
# Pitcairn           [FirePro Server(Sx000), FirePro GCN(Wx000), So...     10
# Polaris 20         [Polaris(RX 500), Polaris Mobile(RX M500), Pol...      4
# Polaris 21         [Radeon Pro Mac(500 Series), Polaris(RX 500), ...      5
# Polaris 23         [Polaris Mobile(M500X), Polaris Mobile(RX M500...      6
# Polaris 24         [Polaris Mobile(M500X), Polaris Mobile(M500), ...      4
# Portola                                    [Graphics(IGP), Graphics]      2
# R100                        [All-In-Wonder(7000), Radeon R100(7200)]      2
# R200               [All-In-Wonder(8500), FireGL(8000), Radeon R20...      4
# R300               [All-In-Wonder(9000), FireGL(9000), Radeon R30...      5
# R350                        [All-In-Wonder(9000), Radeon R300(9800)]      2
# R360                               [FireGL(9000), Radeon R300(9800)]      2
# R420               [All-In-Wonder(X), FireGL(9000), Radeon R400 A...      3
# R423               [FireGL(Vx100), Radeon R400 PCIe(X800), Radeon...      3
# R430               [All-In-Wonder(X), Radeon R400 PCIe(X800), Rad...      3
# R480                [Radeon R400 PCIe(X850), Radeon R400 PCIe(X800)]      2
# R481                  [Radeon R400 AGP(X800), Radeon R400 AGP(X850)]      2
# R520               [All-In-Wonder(X1), FireGL(Vx200), FireGL(Vx30...      4
# R580                    [All-In-Wonder(X1), Radeon R500 PCIe(X1900)]      2
# R580+              [Radeon R500 PCIe(X1950), Radeon R500 AGP(X1950)]      2
# R600                           [FireGL(Vx600), Radeon R600(HD 2900)]      2
# RC410              [Radeon IGP(Xpress 200), Radeon IGP(Xpress 110...      4
# RS100                            [Radeon IGP(300), Radeon IGP(300M)]      2
# RS200                            [Radeon IGP(300M), Radeon IGP(300)]      2
# RS480              [Radeon IGP(Xpress 200), Radeon IGP(Mobility X...      3
# RS482              [Radeon IGP(Xpress 1100 Mobile), Radeon IGP(Xp...      3
# RS485              [Radeon IGP(Xpress 200M), Radeon IGP(Xpress 11...      2
# RS690              [Radeon IGP(1200), Radeon IGP(Xpress 1200 Mobi...      2
# RS780              [TeraScale IGP(3000), TeraScale IGP(Mobility H...      3
# RS880              [TeraScale IGP(Mobility HD 4000), TeraScale IG...      2
# RV200                       [Radeon R200(7500), All-In-Wonder(7000)]      2
# RV250                       [Radeon R200(9000), All-In-Wonder(9000)]      2
# RV280              [Radeon R200(9200), All-In-Wonder(9000), FireM...      3
# RV350              [All-In-Wonder(9000), FireGL(9000), Radeon R30...      6
# RV360              [Radeon R300(9600), All-In-Wonder(9000), Radeo...      3
# RV370              [FireGL(Vx100), Radeon R300(X300), Radeon R300...      7
# RV380              [FireGL(Vx200), Radeon R300(X600), FireMV Mult...      3
# RV410              [FireGL(Vx000), Radeon R400 PCIe(X700), Radeon...      5
# RV505              [Radeon R500 PCIe(X1300), Radeon R500 PCIe(X15...      3
# RV515              [All-In-Wonder(2006 Edition), FireGL(Vx300), R...      7
# RV516              [Radeon R500 PCIe(X1300), FireMV Multi-View(20...      5
# RV530              [FireGL(Vx400), FireGL(Vx200), Radeon R500 PCI...      8
# RV535              [Radeon R500 PCIe(X1650), Radeon R500 AGP(X165...      3
# RV560              [Radeon R500 PCIe(X1650), Radeon R500 AGP(X165...      3
# RV570              [Radeon R500 PCIe(X1950), Radeon R500 AGP(X1950)]      2
# RV610              [Embedded(2000), Radeon R600(HD 2400), Radeon ...      3
# RV620              [Radeon R600(HD 3400), FireMV Multi-View(2000)...      6
# RV630              [FireGL(Vx600), Radeon R600(HD 2600), Radeon R...      3
# RV635              [Radeon R600(HD 2600), Radeon R600(HD 3600), R...      4
# RV670              [FireGL(Vx700), Radeon R600(HD 2900), Radeon R...      5
# RV710              [Radeon R700(HD 4300), Radeon R700(HD 4500), R...      3
# RV730              [FirePro Terascale(Vx700), Radeon R700(HD 4600...      3
# RV770              [FirePro Terascale(Vx700), Radeon R700(HD 4800...      3
# Rage 128                       [Rage GL, Rage 4, All-In-Wonder(128)]      3
# Rage 128 PRO                            [All-In-Wonder(128), Rage 4]      2
# Rage Mobility                     [Rage Mobility, Rage Mobility(Mx)]      2
# Raptor Lake        [HD Graphics(Raptor Lake), HD Graphics-M(Rapto...      2
# Raven              [Vega IGP(Raven Ridge), Vega IGP(Great Horned ...      2
# Redwood            [Northern Islands(HD 6300), Northern Islands(H...      7
# Rembrandt+         [Navi II IGP(Rembrandt Mobile), Console GPU(AMD)]      2
# Robson                       [Vancouver(HD 6300M), London(HD 7300M)]      2
# Rocket Lake        [HD Graphics(Rocket Lake), HD Graphics-W(Rocke...      2
# Sandy Bridge GT1   [HD Graphics(Sandy Bridge), HD Graphics-M(Sand...      2
# Sandy Bridge GT2   [HD Graphics(Sandy Bridge), HD Graphics-M(Sand...      3
# Sandy Bridge GT2+  [HD Graphics(Sandy Bridge), HD Graphics-M(Sand...      2
# Saturn             [FirePro Mobile(Mx100), Solar System(HD 8900M)...      4
# Scrapper           [TeraScale 3 IGP(Trinity Mobile), TeraScale 3 ...      4
# Scrapper Lite      [TeraScale 3 IGP(Trinity Mobile), TeraScale 3 ...      4
# Seymour            [FirePro Mobile(Mx900), Vancouver(HD 6400M), L...      3
# Skylake GT1           [HD Graphics(Skylake), HD Graphics-M(Skylake)]      2
# Skylake GT2        [HD Graphics-M(Skylake), HD Graphics(Skylake),...      3
# Skylake GT3e        [HD Graphics-M(Skylake), HD Graphics-W(Skylake)]      2
# Skylake GT4e       [HD Graphics-M(Skylake), HD Graphics-W(Skylake...      3
# Spectre Lite       [GCN 2.0 IGP(Kaveri Mobile), GCN 2.0 IGP(Kaveri)]      2
# Spectre SL         [GCN 2.0 IGP(Kaveri Mobile), GCN 2.0 IGP(Kaveri)]      2
# Strix Point        [Navi III IGP(Strix Point Mobile), Console GPU...      2
# Sumo               [TeraScale 2 IGP(Sumo Mobile), TeraScale 2 IGP...      2
# Sun                [All-In-One(HD 8000), Solar System(HD 8500M), ...      4
# SuperSumo          [TeraScale 2 IGP(Sumo), TeraScale 2 IGP(Sumo M...      2
# TU102              [GeForce 20, Quadro Turing(Tx000), Quadro Turi...      6
# TU104              [GeForce 20, Quadro Turing(Tx000), Tesla Turin...      5
# TU106              [GeForce 20, GeForce 20 Mobile, Quadro Turing-...      5
# TU116                   [GeForce 16, GeForce 16 Mobile, Mining GPUs]      3
# TU117              [GeForce 16, GeForce 16 Mobile, Quadro Turing-...      4
# Tahiti             [FirePro Server(Sx000), FirePro GCN(Wx000), So...      7
# Thames             [Northern Islands(HD 6500), London(HD 7600M), ...      3
# Tobago             [Pirate Islands(R7 300), Pirate Islands(R9 300...      3
# Tonga              [FirePro GCN(Wx100), Volcanic Islands(R9 200),...      3
# Topaz              [All-In-One(Rx 200), Gem System(R5 M200), Gem ...      5
# Trinidad            [Pirate Islands(R7 300), Pirate Islands(R9 300)]      2
# Tropo              [FirePro Mobile(Wx100M), Gem System(R7 M300), ...      4
# Turks              [FirePro Terascale(Vx900), Northern Islands(HD...      9
# VSA-100                                           [Voodoo4, Voodoo5]      2
# Van Gogh                      [Console GPU(Valve), Console GPU(AMD)]      2
# Vega 10            [Radeon Instinct(MIx), Radeon Pro Vega(Vega Se...      7
# Vega 20            [Radeon Instinct(MIx), Radeon Pro Vega(Vega II...      4
# Venus              [FirePro Mobile(Mx100), Solar System(HD 8800M)...      6
# Wani               [GCN 3.0 IGP(Carrizo Mobile), GCN 3.0 IGP(Bris...      2
# Whistler           [FirePro Mobile(Mx900), Embedded(6000), Vancou...      6

# %%
disp = get_association_df(df, 'name', 'generation')
disp
# Out:
#                                                                       name  \
# generation
# Ada-MW(x000A)            [RTX 2000 Embedded Ada Generation, RTX 2000 Ma...
# Alchemist(Arc 3 Mobile)                  [Arc A350M, Arc A370M, Arc A380M]
# Alchemist(Arc 3)                            [Arc A310, Arc A350, Arc A380]
# Alchemist(Arc 5 Mobile)                  [Arc A550M, Arc A530M, Arc A570M]
# Alchemist(Arc 7 Mobile)                             [Arc A730M, Arc A770M]
# ...                                                                    ...
# XG40(Volari 8000)                            [Volari 8300, Volari 8600 XT]
# XG40(Volari V3)                                  [Volari V3, Volari V3 XT]
# XG40(Volari V5)          [Volari Duo V5 Ultra, Volari V5, Volari V5 Ultra]
# XG40(Volari V8)          [Volari Duo V8 Ultra, Volari V8, Volari V8 Ultra]
# Xe Graphics                     [Iris Xe MAX Graphics, Xe DG1, Xe DG1-SDV]
#
#                          count
# generation
# Ada-MW(x000A)               13
# Alchemist(Arc 3 Mobile)      3
# Alchemist(Arc 3)             3
# Alchemist(Arc 5 Mobile)      3
# Alchemist(Arc 7 Mobile)      2
# ...                        ...
# XG40(Volari 8000)            2
# XG40(Volari V3)              2
# XG40(Volari V5)              3
# XG40(Volari V8)              3
# Xe Graphics                  3
#
# [503 rows x 2 columns]

# %%
disp = get_association_df(df, 'architecture', 'name')
disp
# Out:
#                                                                  architecture  \
# name
# GMA 3000                                     [Generation 4.0, Generation 3.5]
# GeForce 610M                                               [Fermi 2.0, Fermi]
# GeForce 6200 AGP                                             [Celsius, Curie]
# GeForce 710A                                          [Fermi 2.0, Kepler 2.0]
# GeForce 710M                                          [Kepler 2.0, Fermi 2.0]
# GeForce 810M                                              [Fermi 2.0, Kepler]
# GeForce 820M                                              [Fermi 2.0, Kepler]
# GeForce FX 5200                                            [Celsius, Rankine]
# GeForce G105M                                              [Tesla 2.0, Tesla]
# GeForce GT 220                                             [Tesla 2.0, Tesla]
# GeForce GT 320M                                            [Tesla, Tesla 2.0]
# GeForce GT 520 OEM                                         [Fermi 2.0, Fermi]
# GeForce GT 520M                                            [Fermi, Fermi 2.0]
# GeForce GT 550M                                            [Fermi, Fermi 2.0]
# GeForce GT 555M 3 GB                                       [Fermi, Fermi 2.0]
# GeForce GT 610 OEM                                         [Fermi 2.0, Fermi]
# GeForce GT 620M                                            [Fermi, Fermi 2.0]
# GeForce GT 630M                                            [Fermi, Fermi 2.0]
# GeForce GT 635M                                            [Fermi, Fermi 2.0]
# GeForce GT 640M LE                                            [Kepler, Fermi]
# GeForce GT 710                                        [Kepler 2.0, Fermi 2.0]
# GeForce GT 720M                                       [Kepler 2.0, Fermi 2.0]
# GeForce GT 730                                            [Fermi, Kepler 2.0]
# GeForce GT 730M                                          [Kepler, Kepler 2.0]
# GeForce GT 740M                                          [Kepler, Kepler 2.0]
# GeForce GTX 860M                                            [Kepler, Maxwell]
# HD Graphics 6EU Mobile                       [Generation 6.0, Generation 7.0]
# ION                                                        [Tesla 2.0, Tesla]
# NVS 5200M                                                  [Fermi, Fermi 2.0]
# Radeon Pro SSG                                             [GCN 3.0, GCN 5.0]
# Radeon R1E Mobile Graphics                                 [GCN 3.0, GCN 2.0]
# Radeon R2 Mobile Graphics                                  [GCN 2.0, GCN 3.0]
# Radeon R2E Mobile Graphics                                 [GCN 2.0, GCN 3.0]
# Radeon R3 Mobile Graphics                                  [GCN 2.0, GCN 3.0]
# Radeon R4 Mobile Graphics                                  [GCN 2.0, GCN 3.0]
# Radeon R4E Mobile Graphics                                 [GCN 2.0, GCN 3.0]
# Radeon R5 Graphics                                         [GCN 2.0, GCN 3.0]
# Radeon R5 Mobile Graphics                                  [GCN 2.0, GCN 3.0]
# Radeon R5E Mobile Graphics                                 [GCN 2.0, GCN 3.0]
# Radeon R6 M255DX                                           [GCN 3.0, GCN 1.0]
# Radeon R6 Mobile Graphics                                  [GCN 2.0, GCN 3.0]
# Radeon R7 A360                                             [GCN 3.0, GCN 1.0]
# Radeon R7 M260DX                                           [GCN 1.0, GCN 3.0]
# Radeon R7 M265                                             [GCN 3.0, GCN 1.0]
# Radeon R7 M265DX                                           [GCN 1.0, GCN 3.0]
# Radeon R7 M270DX                                           [GCN 1.0, GCN 3.0]
# Radeon R7 M340                                             [GCN 1.0, GCN 3.0]
# Radeon R7 M465                                             [GCN 3.0, GCN 1.0]
# Radeon R7 Mobile Graphics                                  [GCN 2.0, GCN 3.0]
# Radeon R9 M270X                                            [GCN 1.0, GCN 2.0]
# Radeon X1050                                                     [R300, R400]
# UHD Graphics 16EU Mobile    [Generation 11.0, Generation 12.1, Generation ...
# UHD Graphics 24EU Mobile    [Generation 9.5, Generation 11.0, Generation 1...
# UHD Graphics 32EU Mobile                   [Generation 11.0, Generation 12.1]
# UHD Graphics 730                           [Generation 12.1, Generation 12.2]
#
#                             count
# name
# GMA 3000                        2
# GeForce 610M                    2
# GeForce 6200 AGP                2
# GeForce 710A                    2
# GeForce 710M                    2
# GeForce 810M                    2
# GeForce 820M                    2
# GeForce FX 5200                 2
# GeForce G105M                   2
# GeForce GT 220                  2
# GeForce GT 320M                 2
# GeForce GT 520 OEM              2
# GeForce GT 520M                 2
# GeForce GT 550M                 2
# GeForce GT 555M 3 GB            2
# GeForce GT 610 OEM              2
# GeForce GT 620M                 2
# GeForce GT 630M                 2
# GeForce GT 635M                 2
# GeForce GT 640M LE              2
# GeForce GT 710                  2
# GeForce GT 720M                 2
# GeForce GT 730                  2
# GeForce GT 730M                 2
# GeForce GT 740M                 2
# GeForce GTX 860M                2
# HD Graphics 6EU Mobile          2
# ION                             2
# NVS 5200M                       2
# Radeon Pro SSG                  2
# Radeon R1E Mobile Graphics      2
# Radeon R2 Mobile Graphics       2
# Radeon R2E Mobile Graphics      2
# Radeon R3 Mobile Graphics       2
# Radeon R4 Mobile Graphics       2
# Radeon R4E Mobile Graphics      2
# Radeon R5 Graphics              2
# Radeon R5 Mobile Graphics       2
# Radeon R5E Mobile Graphics      2
# Radeon R6 M255DX                2
# Radeon R6 Mobile Graphics       2
# Radeon R7 A360                  2
# Radeon R7 M260DX                2
# Radeon R7 M265                  2
# Radeon R7 M265DX                2
# Radeon R7 M270DX                2
# Radeon R7 M340                  2
# Radeon R7 M465                  2
# Radeon R7 Mobile Graphics       2
# Radeon R9 M270X                 2
# Radeon X1050                    2
# UHD Graphics 16EU Mobile        3
# UHD Graphics 24EU Mobile        3
# UHD Graphics 32EU Mobile        2
# UHD Graphics 730                2

# %%
disp = get_association_df(df, 'manufacturer', 'name')
disp
# Out:
# Empty DataFrame
# Columns: [manufacturer, count]
# Index: []

# %%
disp = get_association_df(df, 'architecture', 'gpu_name')
disp
# Out:
# Empty DataFrame
# Columns: [architecture, count]
# Index: []

# %%
disp = get_association_df(df, 'manufacturer', 'gpu_name')
disp
# Out:
# Empty DataFrame
# Columns: [manufacturer, count]
# Index: []

# %%
disp = get_association_df(df, 'manufacturer', 'generation')
disp
# Out:
#                                manufacturer  count
# generation
# Console GPU(Microsoft)   [NVIDIA, ATI, AMD]      3
# Console GPU(Nintendo)    [ATI, AMD, NVIDIA]      3
# Console GPU(Sony)       [Sony, NVIDIA, AMD]      3

# %%
disp = get_association_df(df, 'generation', 'gpu_name')
disp
# Out:
#                                                           generation  count
# gpu_name
# 18800-1                                                   [EGA, VGA]      2
# AD102              [GeForce 40, Server Ada(Lxx), Workstation Ada(...      3
# AD103              [GeForce 40, GeForce 40 Mobile, Workstation Ad...      4
# AD104              [GeForce 40, GeForce 40 Mobile, Server Ada(Lxx...      5
# AD106                 [GeForce 40, GeForce 40 Mobile, Ada-MW(x000A)]      3
# AD107              [GeForce 40, GeForce 40 Mobile, Ada-MW(x000A),...      4
# Alder Lake         [HD Graphics(Alder Lake), HD Graphics-M(Alder ...      2
# Amethyst           [Gem System(R9 M200), FirePro Mobile(Wx100M), ...      6
# Auburn                                     [Graphics, Graphics(IGP)]      2
# Baffin             [Embedded(9000), Radeon Pro Mac(400 Series), R...     10
# Banks              [Arctic Islands(R5 400), Polaris Mobile(M500),...      4
# Barts              [Northern Islands(HD 6800), Northern Islands(H...      3
# Bearlake           [GMA Graphics-M(GMA 3100 IGP), GMA Graphics(GM...      3
# Blackcomb               [FirePro Mobile(Mx900), Vancouver(HD 6900M)]      2
# Bonaire            [Southern Islands(HD 7700), Sea Islands(HD 870...      5
# Broadwater         [GMA Graphics(GMA 3000 IGP), GMA Graphics-M(GM...      3
# Broadwell GT2      [HD Graphics-M(Broadwell), HD Graphics-W(Broad...      2
# Broadwell GT3e     [HD Graphics(Broadwell), HD Graphics-M(Broadwe...      3
# C51                [Quadro NVS IGP, GeForce 6 IGP, GeForce Go 6 I...      3
# C61                                   [GeForce 6 IGP, GeForce 7 IGP]      2
# C67                           [GeForce 7M IGP(7000M), GeForce 7 IGP]      2
# C77                   [GeForce 8M IGP(8000M), GeForce 9M IGP(9000M)]      2
# C78                                   [GeForce 8 IGP, GeForce 9 IGP]      2
# C79                [GeForce 8M IGP(8000M), GeForce 9M IGP(9000M),...      7
# Caicos             [Embedded(6000), Northern Islands(HD 6400), Al...      9
# Cape Verde         [FirePro GCN(Wx000), Southern Islands(HD 7700)...      8
# Capsaicin          [Pirate Islands(R9 300), FirePro Server(Sx300)...      3
# Cayman             [Northern Islands(HD 6900), FirePro Terascale(...      2
# Cedar              [FirePro Multi-View(2200), Northern Islands(HD...      7
# Chelsea                    [FirePro Mobile(Mx000), London(HD 7700M)]      2
# Coffee Lake GT1    [HD Graphics(Coffee Lake), HD Graphics-M(Coffe...      2
# Coffee Lake GT2    [HD Graphics(Coffee Lake), HD Graphics-M(Coffe...      4
# Comet Lake GT1     [HD Graphics-M(Comet Lake), HD Graphics(Comet ...      2
# Comet Lake GT2     [HD Graphics-M(Comet Lake), HD Graphics(Comet ...      4
# Curacao             [Sea Islands(HD 8800), Volcanic Islands(R7 200)]      2
# Cypress                      [FireStream, Northern Islands(HD 6800)]      2
# DG1                                      [H3C Graphics, Xe Graphics]      2
# DG2-128            [Alchemist(Arc 3), Alchemist(Arc 3 Mobile), Al...      5
# DG2-256            [Alchemist(Arc 5 Mobile), Alchemist(Pro Series...      3
# DG2-512            [Alchemist(Arc 5 Mobile), Alchemist(Arc 7 Mobi...      5
# Devastator         [TeraScale 3 IGP(Trinity Mobile), TeraScale 3 ...      4
# Devastator Lite    [TeraScale 3 IGP(Trinity Mobile), TeraScale 3 ...      4
# Eaglelake          [GMA Graphics(GMA 4500 IGP), GMA Graphics-M(GM...      2
# Ellesmere          [Embedded(9000), Radeon Instinct(MIx), Radeon ...     12
# Emerald            [FirePro Mobile(Mx100), FirePro Mobile(Wx100M)...      3
# Exo                [Pirate Islands(R5 300), All-In-One(Rx 300), G...      4
# Fiji               [Pirate Islands(R9 300), Radeon Instinct(MIx),...      3
# G70                [GeForce 7 PCIe(7800), GeForce Go 7(Go 7000), ...      4
# G71                [Quadro FX Mobile(x500M), GeForce 7 AGP(7600),...      8
# G72                [GeForce 7 PCIe(7200), GeForce 7 PCIe(7300), G...      7
# G72B                             [GeForce Go 7(Go 7000), NVS Mobile]      2
# G73                [GeForce 7 PCIe(7300), GeForce 7 PCIe(7600), G...      6
# G73B               [GeForce 7 PCIe(7300), GeForce 7 AGP(7300), Ge...      5
# G80                [GeForce 8(8800), Quadro FX Tesla(x600), Tesla...      3
# G84                [GeForce 8(8600), GeForce 8M(8000M), Quadro FX...      8
# G86                             [GeForce 8M(8000M), GeForce 8(8500)]      2
# G86S               [GeForce 8(8300), GeForce 8(8400), GeForce 8M(...      8
# G92                [GeForce 8(8800), GeForce 8M(8000M), GeForce 9...     11
# G94                [GeForce 9(9600), GeForce 9M(9700M), GeForce 9...      7
# G94B                     [GeForce 9(9600), GeForce 100, GeForce 200]      3
# G96                [GeForce 9(9500), GeForce 9M(9500M), GeForce 9...      5
# G96C               [GeForce 9(9400), GeForce 9(9500), GeForce 9M(...      9
# G98                             [GeForce 9M(9000M), GeForce 9(9300)]      2
# G98S               [GeForce 8(8400), GeForce 9M(9000M), GeForce 9...      8
# GA100              [Server Ampere(Axx), DRIVE(Axx), GRID(Ax), Min...      4
# GA102              [Server Ampere(Axx), GeForce 30, Workstation A...      4
# GA103              [GeForce 30, GeForce 30 Mobile, Ampere-MW(Ax000)]      3
# GA104              [GeForce 30, Mining GPUs, GeForce 30 Mobile, A...      5
# GA106              [GeForce 30 Mobile, GeForce 30, Workstation Am...      3
# GA107              [Server Ampere(Axx), Workstation Ampere(Ax000)...      7
# GA107S                           [GeForce MX(5xx), Ampere-MW(Ax000)]      2
# GA10B                         [Tegra(Ampere), Console GPU(Nintendo)]      2
# GB202              [GeForce 50, Blackwell PRO W(x000), Server Bla...      3
# GB203              [GeForce 50, GeForce 50 Mobile, Blackwell PRO ...      3
# GB205                                [GeForce 50, GeForce 50 Mobile]      2
# GB206              [GeForce 50, GeForce 50 Mobile, Blackwell PRO ...      3
# GB207                                [GeForce 50, GeForce 50 Mobile]      2
# GF100              [GeForce 400, GeForce 400M, Quadro Fermi(x000)...      5
# GF104              [GeForce 400, GeForce 400M, Quadro Fermi-M(x00...      3
# GF106              [GeForce 400, GeForce 400M, Quadro Fermi(x000)...      5
# GF108              [GeForce 400M, GeForce 400, Quadro Fermi(x000)...     11
# GF110              [GeForce 500, Quadro Fermi-M(x000M), Quadro Pl...      5
# GF114              [GeForce 400, GeForce 500, GeForce 500M, GeFor...      5
# GF116              [GeForce 500, GeForce 400, GeForce 500M, GeFor...      4
# GF116S                                  [GeForce 500M, GeForce 600M]      2
# GF117              [GeForce 600M, NVS Mobile(x200M), GeForce 700M...      6
# GF117B                                  [GeForce 600M, GeForce 800M]      2
# GF119                                   [GeForce 600M, GeForce 500M]      2
# GF119S             [GeForce 400M, GeForce 500, GeForce 600A, NVS ...      9
# GK104              [GeForce 600, GeForce 600M, Quadro Kepler-M(Kx...     12
# GK106              [GeForce 600, GeForce 700M, Quadro Kepler(Kx00...      4
# GK106S             [GeForce 600, GeForce 700M, Quadro Kepler-M(Kx...      4
# GK107              [GeForce 600, GeForce 600M, NVS, Quadro Kepler...     15
# GK110              [Tesla Kepler(Kxx), GeForce 700, Quadro Kepler...      3
# GK110B             [GeForce 700, Quadro Kepler(Kx000), Tesla Kepl...      4
# GK180                               [GeForce 700, Tesla Kepler(Kxx)]      2
# GK208              [GeForce 700M, GeForce 600, GeForce 700A, Quad...      7
# GK208B                     [GeForce 700, GeForce 900M, GeForce 900A]      3
# GM107              [GeForce 700, GeForce 800A, GeForce 800M, Quad...     12
# GM108              [GeForce 800A, GeForce 800M, GeForce 900A, GeF...      5
# GM108S             [GeForce 800M, GeForce 900M, GeForce 900A, Qua...      6
# GM200              [GeForce 900, Quadro Maxwell(Mx000), Tesla Max...      3
# GM204              [GeForce 900, GeForce 900M, GRID(Mx), Quadro M...      6
# GM206              [GeForce 700, GeForce 900, Tesla Maxwell(Mxx),...      5
# GM206S                                   [GeForce 900, GeForce 900M]      2
# GM20B                        [Tegra(Maxwell), Console GPU(Nintendo)]      2
# GP100                      [Quadro Pascal(Px000), Tesla Pascal(Pxx)]      2
# GP102              [Quadro Pascal(Px000), Tesla Pascal(Pxx), GeFo...      4
# GP104              [GeForce 10, Quadro Pascal(Px000), Tesla Pasca...      6
# GP106              [GeForce 10, GeForce 10 Mobile, Mining GPUs, Q...      6
# GP107              [GeForce 10, GeForce 10 Mobile, Quadro Pascal(...      7
# GP108              [GeForce 10, GeForce MX(1xx), Quadro Pascal-M(...      5
# GP108B                            [GeForce MX(2xx), GeForce MX(3xx)]      2
# GT200B             [GeForce 200, Quadro FX Tesla(x800), Tesla(x10...      3
# GT216              [GeForce 200, GeForce 200M, GeForce 300, GeFor...      9
# GT218                                   [GeForce 300M, GeForce 400M]      2
# GT218S             [GeForce 8(8400), ION, GeForce 200, GeForce 30...     15
# GV100              [Tesla Volta(Vxx), GeForce 10, Quadro Volta(Vx...      4
# Haswell GT1           [HD Graphics(Haswell), HD Graphics-M(Haswell)]      2
# Haswell GT2        [HD Graphics-M(Haswell), HD Graphics(Haswell),...      3
# Haswell GT3e          [HD Graphics(Haswell), HD Graphics-M(Haswell)]      2
# Hawaii             [FirePro Server(Sx100), FirePro GCN(Wx100), Vo...      3
# Hawk Point         [Navi III IGP(Hawx Point Mobile), Console GPU(...      2
# Heathrow                   [FirePro Mobile(Mx000), London(HD 7800M)]      2
# Ironlake            [HD Graphics(Westmere), HD Graphics-M(Westmere)]      2
# Ivy Bridge GT1     [HD Graphics(Ivy Bridge), HD Graphics-M(Ivy Br...      2
# Ivy Bridge GT2     [HD Graphics(Ivy Bridge), HD Graphics-M(Ivy Br...      3
# Jet                [All-In-One(Rx 200), Gem System(R5 M200), Gem ...      8
# Kaby Lake GT1      [HD Graphics(Kaby Lake), HD Graphics-M(Kaby La...      2
# Kaby Lake GT2      [HD Graphics-M(Kaby Lake), HD Graphics(Kaby La...      4
# Kalindi            [GCN 2.0 IGP(Temash Mobile), GCN 2.0 IGP(Kabin...      3
# Knights Corner                [Knights Corner(x100), Knights Corner]      2
# Lakeport           [GMA Graphics(GMA 950 IGP), GMA Graphics-M(GMA...      3
# Lexa               [Polaris(RX 500), Embedded(9000), Radeon Pro P...      7
# Litho                     [Gem System(R7 M300), Gem System(R7 M400)]      2
# Loveland           [TeraScale 2 IGP(Palm Mobile), TeraScale 2 IGP...      3
# M10                            [Mobility FireGL, M1x(Mobility 9000)]      2
# M11                            [Mobility FireGL, M1x(Mobility 9000)]      2
# M22                       [Mobility FireGL(V3xxx), M2x(Mobility X1)]      2
# M24                       [Mobility FireGL(V3xxx), M2x(Mobility X1)]      2
# M26                       [Mobility FireGL(V5xxx), M2x(Mobility X1)]      2
# M3                           [Rage Mobility(128), Rage Mobility(Mx)]      2
# M4                           [Rage Mobility(128), Rage Mobility(Mx)]      2
# M56                       [Mobility FireGL(V5xxx), M5x(Mobility X1)]      2
# M64                             [M6x(Mobility X1), M6x(Mobility X2)]      2
# M66                [M6x(Mobility X1), Mobility FireGL(V5xxx), M6x...      3
# M7                              [Mobility FireGL, M7(Mobility 7500)]      2
# M71                        [M7x(Mobility HD 2000), M7x(Mobility X2)]      2
# M76                  [Mobility FireGL(V5xxx), M7x(Mobility HD 2000)]      2
# M86                  [Mobility FireGL(V5xxx), M8x(Mobility HD 3600)]      2
# M9                              [Mobility FireGL, M9(Mobility 9000)]      2
# M92                [M9x(Mobility HD 4300), M9x(Mobility HD 4500),...      4
# M93                [M9x(Mobility HD 4300), M9x(Mobility HD 4500),...      3
# M96                [FirePro Mobility(M5xxx), M9x(Mobility HD 4600...      5
# M97                 [FirePro Mobility(M7xxx), M9x(Mobility HD 4800)]      2
# Mach64 GT-B                         [Rage 2, All-In-Wonder(3D Rage)]      2
# Mach64 LT                                    [Rage Mobility, Rage 3]      2
# Malta              [Southern Islands(HD 7900), Sea Islands(HD 8900)]      2
# Mars               [FirePro Mobile(Mx100), All-In-One(HD 8000), S...      7
# Meso               [Gem System(R5 M300), All-In-One(Rx 300), Gem ...      8
# Montara            [Extreme Graphics 2(Mobile IGP), Graphics-M(IGP)]      2
# NV10                                   [GeForce 256, Quadro Celsius]      2
# NV11                                [GeForce 2 MX, GeForce 2 MX PCI]      2
# NV11B              [GeForce2 Go, Quadro2 Celcius, GeForce 2 MX, G...      5
# NV15                                    [GeForce 2, Quadro2 Celcius]      2
# NV17               [GeForce4 Go, GeForce 4 MX, Quadro4 Go, Quadro...      6
# NV18               [GeForce4 Go, GeForce 4 MX, Quadro4 Celcius(x8...      4
# NV18C              [GeForce 6 AGP(6200), GeForce FX(5200), GeForc...      5
# NV20                                    [GeForce 3, Quadro2 Celcius]      2
# NV25               [GeForce 4 Ti, Quadro4 Celcius(x00), Quadro4 C...      3
# NV28               [GeForce4 Go, GeForce 4 Ti, Quadro4 Celcius(x8...      4
# NV30                     [GeForce FX(5800), Quadro FX Rankine(x000)]      2
# NV31               [GeForce FX(5600), GeForce FX Go 5(Go 5000), Q...      3
# NV34               [GeForce FX(5100), GeForce FX(5200), GeForce F...      5
# NV34B              [GeForce FX(5200), GeForce FX Go 5(Go 5000), Q...      4
# NV35               [GeForce FX(5900), GeForce PCX, Quadro FX Rank...      3
# NV36               [GeForce FX(5700), Quadro FX Go, GeForce FX Go...      3
# NV36B                    [GeForce FX(5700), Quadro FX Rankine(x100)]      2
# NV37               [GeForce PCX, Quadro FX Rankine(x300), Quadro ...      3
# NV38               [GeForce FX(5900), GeForce PCX, Quadro FX Rank...      3
# NV40                  [GeForce 6 AGP(6800), Quadro FX Rankine(x000)]      2
# NV41               [GeForce 6 PCIe(6800), GeForce Go 6(Go 6000), ...      5
# NV43               [GeForce 6 PCIe(6200), GeForce 6 PCI(6200), Ge...     10
# NV44               [GeForce 6 AGP(6200), GeForce 6 PCIe(6200), Ge...      6
# NV44B              [GeForce 6 AGP(6200), GeForce 7 PCIe(7100), Ge...      3
# NV45                   [GeForce 6 PCIe(6800), Quadro FX Curie(x400)]      2
# Navi 10            [Radeon Pro Navi(Navi Series), Radeon Pro Mac(...      4
# Navi 12            [Radeon Pro Mac(Navi Mobile), Radeon Pro Navi(...      2
# Navi 14            [Radeon Pro Mac(Navi Mobile), Radeon Pro Mobil...      6
# Navi 21            [Navi II(RX 6000), Radeon Pro Navi(Navi II Ser...      3
# Navi 22                    [Navi II(RX 6000), Navi Mobile(RX 6000M)]      2
# Navi 23            [Radeon Pro Navi(Navi II Series), Radeon Pro M...      5
# Navi 24            [Radeon Pro Navi(Navi II Series), Radeon Pro M...      4
# Navi 31            [Navi III(RX 7000), Radeon Pro Navi(Navi III S...      3
# Navi 32            [Radeon Pro Navi(Navi III Series), Navi III(RX...      3
# Navi 33            [Radeon Pro Navi(Navi III Series), Navi III(RX...      3
# Navi 48            [Radeon Pro Navi(Navi IV Series), Navi IV(RX 9...      2
# Neptune                [Solar System(HD 8900M), Gem System(R9 M200)]      2
# Oland              [Sea Islands(HD 8500), Sea Islands(HD 8600), V...     10
# Onega                     [All-In-One(HD 6000), All-In-One(HD 7000)]      2
# Opal               [FirePro Mobile(Mx100), All-In-One(Rx 200), Ge...      7
# Park               [Northern Islands(HD 6200), Northern Islands(H...      2
# Phoenix            [Navi III IGP(Phoenix Mobile), Console GPU(AMD...      3
# Picasso-M              [Vega IGP(Picasso Mobile), Vega IGP(Picasso)]      2
# Pineview           [GMA Graphics(GMA 3100 IGP), GMA Graphics-M(GM...      2
# Pitcairn           [FirePro Server(Sx000), FirePro GCN(Wx000), So...     10
# Polaris 20         [Polaris(RX 500), Polaris Mobile(RX M500), Pol...      4
# Polaris 21         [Radeon Pro Mac(500 Series), Polaris(RX 500), ...      5
# Polaris 23         [Polaris Mobile(M500X), Polaris Mobile(RX M500...      6
# Polaris 24         [Polaris Mobile(M500X), Polaris Mobile(M500), ...      4
# Portola                                    [Graphics(IGP), Graphics]      2
# R100                        [All-In-Wonder(7000), Radeon R100(7200)]      2
# R200               [All-In-Wonder(8500), FireGL(8000), Radeon R20...      4
# R300               [All-In-Wonder(9000), FireGL(9000), Radeon R30...      5
# R350                        [All-In-Wonder(9000), Radeon R300(9800)]      2
# R360                               [FireGL(9000), Radeon R300(9800)]      2
# R420               [All-In-Wonder(X), FireGL(9000), Radeon R400 A...      3
# R423               [FireGL(Vx100), Radeon R400 PCIe(X800), Radeon...      3
# R430               [All-In-Wonder(X), Radeon R400 PCIe(X800), Rad...      3
# R480                [Radeon R400 PCIe(X850), Radeon R400 PCIe(X800)]      2
# R481                  [Radeon R400 AGP(X800), Radeon R400 AGP(X850)]      2
# R520               [All-In-Wonder(X1), FireGL(Vx200), FireGL(Vx30...      4
# R580                    [All-In-Wonder(X1), Radeon R500 PCIe(X1900)]      2
# R580+              [Radeon R500 PCIe(X1950), Radeon R500 AGP(X1950)]      2
# R600                           [FireGL(Vx600), Radeon R600(HD 2900)]      2
# RC410              [Radeon IGP(Xpress 200), Radeon IGP(Xpress 110...      4
# RS100                            [Radeon IGP(300), Radeon IGP(300M)]      2
# RS200                            [Radeon IGP(300M), Radeon IGP(300)]      2
# RS480              [Radeon IGP(Xpress 200), Radeon IGP(Mobility X...      3
# RS482              [Radeon IGP(Xpress 1100 Mobile), Radeon IGP(Xp...      3
# RS485              [Radeon IGP(Xpress 200M), Radeon IGP(Xpress 11...      2
# RS690              [Radeon IGP(1200), Radeon IGP(Xpress 1200 Mobi...      2
# RS780              [TeraScale IGP(3000), TeraScale IGP(Mobility H...      3
# RS880              [TeraScale IGP(Mobility HD 4000), TeraScale IG...      2
# RV200                       [Radeon R200(7500), All-In-Wonder(7000)]      2
# RV250                       [Radeon R200(9000), All-In-Wonder(9000)]      2
# RV280              [Radeon R200(9200), All-In-Wonder(9000), FireM...      3
# RV350              [All-In-Wonder(9000), FireGL(9000), Radeon R30...      6
# RV360              [Radeon R300(9600), All-In-Wonder(9000), Radeo...      3
# RV370              [FireGL(Vx100), Radeon R300(X300), Radeon R300...      7
# RV380              [FireGL(Vx200), Radeon R300(X600), FireMV Mult...      3
# RV410              [FireGL(Vx000), Radeon R400 PCIe(X700), Radeon...      5
# RV505              [Radeon R500 PCIe(X1300), Radeon R500 PCIe(X15...      3
# RV515              [All-In-Wonder(2006 Edition), FireGL(Vx300), R...      7
# RV516              [Radeon R500 PCIe(X1300), FireMV Multi-View(20...      5
# RV530              [FireGL(Vx400), FireGL(Vx200), Radeon R500 PCI...      8
# RV535              [Radeon R500 PCIe(X1650), Radeon R500 AGP(X165...      3
# RV560              [Radeon R500 PCIe(X1650), Radeon R500 AGP(X165...      3
# RV570              [Radeon R500 PCIe(X1950), Radeon R500 AGP(X1950)]      2
# RV610              [Embedded(2000), Radeon R600(HD 2400), Radeon ...      3
# RV620              [Radeon R600(HD 3400), FireMV Multi-View(2000)...      6
# RV630              [FireGL(Vx600), Radeon R600(HD 2600), Radeon R...      3
# RV635              [Radeon R600(HD 2600), Radeon R600(HD 3600), R...      4
# RV670              [FireGL(Vx700), Radeon R600(HD 2900), Radeon R...      5
# RV710              [Radeon R700(HD 4300), Radeon R700(HD 4500), R...      3
# RV730              [FirePro Terascale(Vx700), Radeon R700(HD 4600...      3
# RV770              [FirePro Terascale(Vx700), Radeon R700(HD 4800...      3
# Rage 128                       [Rage GL, Rage 4, All-In-Wonder(128)]      3
# Rage 128 PRO                            [All-In-Wonder(128), Rage 4]      2
# Rage Mobility                     [Rage Mobility, Rage Mobility(Mx)]      2
# Raptor Lake        [HD Graphics(Raptor Lake), HD Graphics-M(Rapto...      2
# Raven              [Vega IGP(Raven Ridge), Vega IGP(Great Horned ...      2
# Redwood            [Northern Islands(HD 6300), Northern Islands(H...      7
# Rembrandt+         [Navi II IGP(Rembrandt Mobile), Console GPU(AMD)]      2
# Robson                       [Vancouver(HD 6300M), London(HD 7300M)]      2
# Rocket Lake        [HD Graphics(Rocket Lake), HD Graphics-W(Rocke...      2
# Sandy Bridge GT1   [HD Graphics(Sandy Bridge), HD Graphics-M(Sand...      2
# Sandy Bridge GT2   [HD Graphics(Sandy Bridge), HD Graphics-M(Sand...      3
# Sandy Bridge GT2+  [HD Graphics(Sandy Bridge), HD Graphics-M(Sand...      2
# Saturn             [FirePro Mobile(Mx100), Solar System(HD 8900M)...      4
# Scrapper           [TeraScale 3 IGP(Trinity Mobile), TeraScale 3 ...      4
# Scrapper Lite      [TeraScale 3 IGP(Trinity Mobile), TeraScale 3 ...      4
# Seymour            [FirePro Mobile(Mx900), Vancouver(HD 6400M), L...      3
# Skylake GT1           [HD Graphics(Skylake), HD Graphics-M(Skylake)]      2
# Skylake GT2        [HD Graphics-M(Skylake), HD Graphics(Skylake),...      3
# Skylake GT3e        [HD Graphics-M(Skylake), HD Graphics-W(Skylake)]      2
# Skylake GT4e       [HD Graphics-M(Skylake), HD Graphics-W(Skylake...      3
# Spectre Lite       [GCN 2.0 IGP(Kaveri Mobile), GCN 2.0 IGP(Kaveri)]      2
# Spectre SL         [GCN 2.0 IGP(Kaveri Mobile), GCN 2.0 IGP(Kaveri)]      2
# Strix Point        [Navi III IGP(Strix Point Mobile), Console GPU...      2
# Sumo               [TeraScale 2 IGP(Sumo Mobile), TeraScale 2 IGP...      2
# Sun                [All-In-One(HD 8000), Solar System(HD 8500M), ...      4
# SuperSumo          [TeraScale 2 IGP(Sumo), TeraScale 2 IGP(Sumo M...      2
# TU102              [GeForce 20, Quadro Turing(Tx000), Quadro Turi...      6
# TU104              [GeForce 20, Quadro Turing(Tx000), Tesla Turin...      5
# TU106              [GeForce 20, GeForce 20 Mobile, Quadro Turing-...      5
# TU116                   [GeForce 16, GeForce 16 Mobile, Mining GPUs]      3
# TU117              [GeForce 16, GeForce 16 Mobile, Quadro Turing-...      4
# Tahiti             [FirePro Server(Sx000), FirePro GCN(Wx000), So...      7
# Thames             [Northern Islands(HD 6500), London(HD 7600M), ...      3
# Tobago             [Pirate Islands(R7 300), Pirate Islands(R9 300...      3
# Tonga              [FirePro GCN(Wx100), Volcanic Islands(R9 200),...      3
# Topaz              [All-In-One(Rx 200), Gem System(R5 M200), Gem ...      5
# Trinidad            [Pirate Islands(R7 300), Pirate Islands(R9 300)]      2
# Tropo              [FirePro Mobile(Wx100M), Gem System(R7 M300), ...      4
# Turks              [FirePro Terascale(Vx900), Northern Islands(HD...      9
# VSA-100                                           [Voodoo4, Voodoo5]      2
# Van Gogh                      [Console GPU(Valve), Console GPU(AMD)]      2
# Vega 10            [Radeon Instinct(MIx), Radeon Pro Vega(Vega Se...      7
# Vega 20            [Radeon Instinct(MIx), Radeon Pro Vega(Vega II...      4
# Venus              [FirePro Mobile(Mx100), Solar System(HD 8800M)...      6
# Wani               [GCN 3.0 IGP(Carrizo Mobile), GCN 3.0 IGP(Bris...      2
# Whistler           [FirePro Mobile(Mx900), Embedded(6000), Vancou...      6

# %%
df = df[df['architecture'].isna() == False] # drop all null architectures

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3092 entries, 0 to 3205
# Data columns (total 54 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   manufacturer                      3092 non-null   object
#  1   name                              3092 non-null   object
#  2   gpu_name                          3092 non-null   object
#  3   generation                        3092 non-null   object
#  4   base_clock_mhz                    3092 non-null   float64
#  5   boost_clock_mhz                   3092 non-null   float64
#  6   architecture                      3092 non-null   object
#  7   foundry                           2967 non-null   object
#  8   process_size_nm                   3088 non-null   float64
#  9   transistor_count_m                2851 non-null   float64
#  10  transistor_density_k_mm2          2822 non-null   float64
#  11  die_size_mm2                      2887 non-null   float64
#  12  chip_package                      1858 non-null   object
#  13  release_date                      3030 non-null   object
#  14  bus_interface                     3051 non-null   object
#  15  memory_clock_mhz                  2626 non-null   float64
#  16  memory_size_gb                    3092 non-null   float64
#  17  memory_bus_bits                   2626 non-null   float64
#  18  memory_bandwidth_gb_s             2626 non-null   float64
#  19  memory_type                       3092 non-null   object
#  20  shading_units                     3092 non-null   int64
#  21  texture_mapping_units             3092 non-null   int64
#  22  render_output_processors          3092 non-null   int64
#  23  streaming_multiprocessors         3092 non-null   int64
#  24  tensor_cores                      3092 non-null   int64
#  25  ray_tracing_cores                 3092 non-null   int64
#  26  l1_cache_kb                       3092 non-null   float64
#  27  l2_cache_mb                       3092 non-null   float64
#  28  thermal_design_power_w            2378 non-null   float64
#  29  board_length_mm                   1049 non-null   float64
#  30  board_width_mm                    548 non-null    float64
#  31  board_slot_width                  2748 non-null   object
#  32  suggested_psu_w                   1624 non-null   float64
#  33  power_connectors                  758 non-null    object
#  34  display_connectors                1484 non-null   object
#  35  directx_major_version             2997 non-null   float64
#  36  directx_minor_version             2997 non-null   float64
#  37  opengl_major_version              2982 non-null   float64
#  38  opengl_minor_version              2982 non-null   float64
#  39  vulkan_major_version              1453 non-null   float64
#  40  vulkan_minor_version              1453 non-null   float64
#  41  opencl_major_version              2153 non-null   float64
#  42  opencl_minor_version              2153 non-null   float64
#  43  cuda_major_version                1054 non-null   float64
#  44  cuda_minor_version                1054 non-null   float64
#  45  shader_model_major_version        2512 non-null   float64
#  46  shader_model_minor_version        2512 non-null   float64
#  47  pixel_rate_gpixel_s               3092 non-null   float64
#  48  texture_rate_gtexel_s             3092 non-null   float64
#  49  half_float_performance_gflop_s    945 non-null    float64
#  50  single_float_performance_gflop_s  2288 non-null   float64
#  51  double_float_performance_gflop_s  1682 non-null   float64
#  52  tpu_id                            3092 non-null   object
#  53  tpu_url                           3092 non-null   object
# dtypes: float64(33), int64(6), object(15)
# memory usage: 1.3+ MB

# %%
df.to_csv('../Source/Clean/2025-08.csv', index=False)
