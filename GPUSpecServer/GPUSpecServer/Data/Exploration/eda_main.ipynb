# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("../Source/Raw/2025-08.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3206 entries, 0 to 3205
# Data columns (total 54 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   manufacturer                      3206 non-null   object
#  1   name                              3206 non-null   object
#  2   gpu_name                          3206 non-null   object
#  3   generation                        3206 non-null   object
#  4   base_clock_mhz                    3206 non-null   float64
#  5   boost_clock_mhz                   3206 non-null   float64
#  6   architecture                      3178 non-null   object
#  7   foundry                           3081 non-null   object
#  8   process_size_nm                   3202 non-null   float64
#  9   transistor_count_m                2963 non-null   float64
#  10  transistor_density_k_mm2          2928 non-null   float64
#  11  die_size_mm2                      2994 non-null   float64
#  12  chip_package                      1927 non-null   object
#  13  release_date                      3140 non-null   object
#  14  bus_interface                     3157 non-null   object
#  15  memory_clock_mhz                  2740 non-null   float64
#  16  memory_size_gb                    3206 non-null   float64
#  17  memory_bus_bits                   2740 non-null   float64
#  18  memory_bandwidth_gb_s             2740 non-null   float64
#  19  memory_type                       3206 non-null   object
#  20  shading_units                     3206 non-null   int64
#  21  texture_mapping_units             3206 non-null   int64
#  22  render_output_processors          3206 non-null   int64
#  23  streaming_multiprocessors         3206 non-null   int64
#  24  tensor_cores                      3206 non-null   int64
#  25  ray_tracing_cores                 3206 non-null   int64
#  26  l1_cache_kb                       3206 non-null   float64
#  27  l2_cache_mb                       3206 non-null   float64
#  28  thermal_design_power_w            2486 non-null   float64
#  29  board_length_mm                   1118 non-null   float64
#  30  board_width_mm                    583 non-null    float64
#  31  board_slot_width                  2841 non-null   object
#  32  suggested_psu_w                   1705 non-null   float64
#  33  power_connectors                  782 non-null    object
#  34  display_connectors                1564 non-null   object
#  35  directx_major_version             3103 non-null   float64
#  36  directx_minor_version             3103 non-null   float64
#  37  opengl_major_version              3082 non-null   float64
#  38  opengl_minor_version              3082 non-null   float64
#  39  vulkan_major_version              1453 non-null   float64
#  40  vulkan_minor_version              1453 non-null   float64
#  41  opencl_major_version              2233 non-null   float64
#  42  opencl_minor_version              2233 non-null   float64
#  43  cuda_major_version                1077 non-null   float64
#  44  cuda_minor_version                1077 non-null   float64
#  45  shader_model_major_version        2594 non-null   float64
#  46  shader_model_minor_version        2594 non-null   float64
#  47  pixel_rate_gpixel_s               3206 non-null   float64
#  48  texture_rate_gtexel_s             3206 non-null   float64
#  49  half_float_performance_gflop_s    945 non-null    float64
#  50  single_float_performance_gflop_s  2369 non-null   float64
#  51  double_float_performance_gflop_s  1696 non-null   float64
#  52  tpu_id                            3206 non-null   object
#  53  tpu_url                           3206 non-null   object
# dtypes: float64(33), int64(6), object(15)
# memory usage: 1.3+ MB

# %%
nan_columns = df.columns[df.isnull().any()]

print("Columns with NaN values:")
print(nan_columns)
# Out:
# Columns with NaN values:
# Index(['architecture', 'foundry', 'process_size_nm', 'transistor_count_m',
#        'transistor_density_k_mm2', 'die_size_mm2', 'chip_package',
#        'release_date', 'bus_interface', 'memory_clock_mhz', 'memory_bus_bits',
#        'memory_bandwidth_gb_s', 'thermal_design_power_w', 'board_length_mm',
#        'board_width_mm', 'board_slot_width', 'suggested_psu_w',
#        'power_connectors', 'display_connectors', 'directx_major_version',
#        'directx_minor_version', 'opengl_major_version', 'opengl_minor_version',
#        'vulkan_major_version', 'vulkan_minor_version', 'opencl_major_version',
#        'opencl_minor_version', 'cuda_major_version', 'cuda_minor_version',
#        'shader_model_major_version', 'shader_model_minor_version',
#        'half_float_performance_gflop_s', 'single_float_performance_gflop_s',
#        'double_float_performance_gflop_s'],
#       dtype='object')

# %%
def get_association_df(df, parent, child):
    options = df.groupby([child])[parent].unique()
    count = df.groupby([child])[parent].nunique()
    
    association_df = pd.DataFrame(data={f'{parent}':options, 'count':count})
    association_df = association_df[association_df['count']>1]
    return association_df

# %%
#df['release_date'] = pd.to_datetime(df['release_date'])
#df.sort_values(by='release_date', ascending=False, inplace=True)
#df.drop_duplicates(subset=['name'], inplace=True)
#df

# %%
disp = get_association_df(df, 'manufacturer', 'architecture')

df = df[~((df['manufacturer']=='AMD') & (df['architecture']=='TeraScale'))] # remove all AMD manufactured chips from terascale architecture
df = df[~((df['manufacturer']=='ATI') & (df['architecture']=='TeraScale 2'))] # remove all ATI manufactured chips from terascale 2 architecture
df = df[~((df['manufacturer']=='AMD') & (df['architecture']=='Ultra-Threaded SE'))] # remove all AMD manufactured chips from UT SE architecture

disp
# Out:
#                   manufacturer  count
# architecture
# TeraScale           [ATI, AMD]      2
# TeraScale 2         [AMD, ATI]      2
# Ultra-Threaded SE   [ATI, AMD]      2

# %%
get_association_df(df, 'architecture', 'generation')
# Out:
#                                                                     architecture  \
# generation
# All-In-One(Rx 200)                               [TeraScale 2, GCN 1.0, GCN 3.0]
# All-In-One(Rx 300)                                            [GCN 1.0, GCN 3.0]
# All-In-Wonder(2006 Edition)                            [R300, Ultra-Threaded SE]
# All-In-Wonder(7000)                                             [Rage 6, Rage 7]
# All-In-Wonder(9000)                                               [R300, Rage 7]
# All-In-Wonder(X)                                                    [R400, R300]
# Arctic Islands(RX 400)                                        [GCN 2.0, GCN 4.0]
# Console GPU(AMD)                                  [RDNA 3.0, RDNA 3.5, RDNA 2.0]
# Console GPU(Microsoft)           [Kelvin, TeraScale, GCN 1.0, GCN 2.0, RDNA 2.0]
# Console GPU(Nintendo)          [Rage 5, Ultra-Threaded SE, TeraScale 2, Maxwe...
# Console GPU(Sony)              [nan, Curie, PowerVR Series5XT, GCN 2.0, RDNA ...
# Data Center GPU(Arctic Sound)                 [Generation 12.5, Generation 12.7]
# Embedded(8000)                                       [GCN 1.0, GCN 2.0, GCN 3.0]
# FireGL(9000)                                                        [R300, R400]
# FireGL(Vx100)                                                       [R300, R400]
# FireGL(Vx200)                                          [R300, Ultra-Threaded SE]
# FireMV Multi-View(2000)             [R300, Rage 7, Ultra-Threaded SE, TeraScale]
# FirePro GCN(Wx100)                                   [GCN 1.0, GCN 2.0, GCN 3.0]
# FirePro Mobile(Mx000)                                     [TeraScale 2, GCN 1.0]
# FirePro Mobile(Mx100)                                         [GCN 1.0, GCN 2.0]
# FirePro Mobile(Wx100M)                               [GCN 1.0, GCN 2.0, GCN 3.0]
# FirePro Server(Sx100)                                         [GCN 2.0, GCN 3.0]
# FirePro Terascale(Vx900)                              [TeraScale 2, TeraScale 3]
# GMA Graphics-M(GMA 3000 IGP)                    [Generation 3.5, Generation 4.0]
# GRID(Mx)                                                  [Maxwell 2.0, Maxwell]
# GeForce 10                                               [Pascal, Volta, Kepler]
# GeForce 100M                                                  [Tesla, Tesla 2.0]
# GeForce 20 Mobile                                               [Turing, Ampere]
# GeForce 200                                                   [Tesla 2.0, Tesla]
# GeForce 200M                                                  [Tesla, Tesla 2.0]
# GeForce 300                                                   [Tesla 2.0, Tesla]
# GeForce 300M                                                  [Tesla, Tesla 2.0]
# GeForce 40                                                [Ada Lovelace, Ampere]
# GeForce 400                                        [Tesla 2.0, Fermi, Fermi 2.0]
# GeForce 400M                                       [Fermi, Tesla 2.0, Fermi 2.0]
# GeForce 500                                        [Fermi 2.0, Fermi, Tesla 2.0]
# GeForce 500M                                                  [Fermi, Fermi 2.0]
# GeForce 6 AGP(6200)                                             [Celsius, Curie]
# GeForce 600                               [Fermi 2.0, Fermi, Kepler, Kepler 2.0]
# GeForce 600M                                          [Fermi 2.0, Fermi, Kepler]
# GeForce 700                    [Kepler, Fermi 2.0, Kepler 2.0, Fermi, Maxwell...
# GeForce 700A                                     [Fermi 2.0, Kepler 2.0, Kepler]
# GeForce 700M                                     [Fermi 2.0, Kepler 2.0, Kepler]
# GeForce 8(8400)                                               [Tesla, Tesla 2.0]
# GeForce 800A                                    [Fermi 2.0, Kepler 2.0, Maxwell]
# GeForce 800M                            [Fermi 2.0, Kepler 2.0, Maxwell, Kepler]
# GeForce 9(9300)                                               [Tesla, Tesla 2.0]
# GeForce 9(9400)                                               [Tesla, Tesla 2.0]
# GeForce 900A                                               [Kepler 2.0, Maxwell]
# GeForce 900M                                  [Maxwell 2.0, Kepler 2.0, Maxwell]
# GeForce FX(5200)                                              [Celsius, Rankine]
# GeForce MX(1xx)                                                [Maxwell, Pascal]
# GeForce MX(5xx)                                                 [Turing, Ampere]
# GeForce PCX                                                   [Rankine, Celsius]
# GeForce4 Go                                                    [Celsius, Kelvin]
# Gem System Hybrid(Rx M200)                                    [GCN 3.0, GCN 1.0]
# Gem System Hybrid(Rx M300)                                    [GCN 1.0, GCN 3.0]
# Gem System Hybrid(Rx M400)                                    [GCN 1.0, GCN 3.0]
# Gem System(R5 M200)                                           [GCN 1.0, GCN 3.0]
# Gem System(R5 M300)                                           [GCN 3.0, GCN 1.0]
# Gem System(R5 M400)                                           [GCN 1.0, GCN 3.0]
# Gem System(R7 M200)                                           [GCN 3.0, GCN 1.0]
# Gem System(R7 M300)                                           [GCN 1.0, GCN 3.0]
# Gem System(R7 M400)                                           [GCN 3.0, GCN 1.0]
# Gem System(R9 M200)                                  [GCN 1.0, GCN 3.0, GCN 2.0]
# Gem System(R9 M300)                                  [GCN 1.0, GCN 2.0, GCN 3.0]
# Gem System(R9 M400)                                           [GCN 2.0, GCN 3.0]
# Graphics                                                  [i740, Generation 1.0]
# Graphics(IGP)                                             [i740, Generation 1.0]
# Graphics-M(IGP)                                 [Generation 1.0, Generation 2.0]
# ION                                                           [Tesla 2.0, Tesla]
# M1x(Mobility 9000)                                                  [R300, R400]
# M2x(Mobility X1)                                                    [R300, R400]
# M7x(Mobility HD 2000)                             [Ultra-Threaded SE, TeraScale]
# Mining GPUs                                      [Pascal, Volta, Ampere, Turing]
# Mobility FireGL                                                   [Rage 7, R300]
# Mobility FireGL(V5xxx)                      [R400, Ultra-Threaded SE, TeraScale]
# NVS                                      [Tesla 2.0, Kepler, Fermi 2.0, Maxwell]
# NVS Mobile                                                        [Curie, Tesla]
# NVS Mobile(x200M)                                             [Fermi 2.0, Fermi]
# Pirate Islands(R5 300)                                    [TeraScale 2, GCN 1.0]
# Pirate Islands(R7 300)                                        [GCN 1.0, GCN 2.0]
# Pirate Islands(R9 300)                               [GCN 2.0, GCN 1.0, GCN 3.0]
# Polaris Mobile(M500)                                 [GCN 1.0, GCN 3.0, GCN 4.0]
# Polaris Mobile(M500X)                                         [GCN 3.0, GCN 4.0]
# Polaris Mobile(M600)                                 [GCN 1.0, GCN 3.0, GCN 4.0]
# Polaris(RX 500)                                               [GCN 4.0, GCN 1.0]
# Polaris(RX 600)                                               [GCN 3.0, GCN 4.0]
# Quadro FX Go                                                    [Rankine, Curie]
# Quadro FX Mobile(x800M)                                       [Tesla, Tesla 2.0]
# Quadro FX Rankine(x000)                                         [Rankine, Curie]
# Quadro FX Tesla(x600)                                             [Curie, Tesla]
# Quadro FX Tesla(x800)                                         [Tesla 2.0, Tesla]
# Quadro Fermi(x000)                                 [Fermi, Tesla 2.0, Fermi 2.0]
# Quadro Fermi-M(x000M)                                         [Fermi, Fermi 2.0]
# Quadro Kepler(Kx200)                                           [Maxwell, Kepler]
# Quadro Kepler-M(Kx100M)                                     [Kepler, Kepler 2.0]
# Quadro Maxwell-M(Mx000M)                                  [Maxwell, Maxwell 2.0]
# Quadro Maxwell-M(Mx200)                                   [Maxwell, Maxwell 2.0]
# Quadro NVS                                      [Rankine, Celsius, Curie, Tesla]
# Quadro2 Celcius                                                [Celsius, Kelvin]
# Quadro4 Celcius(x00)                                           [Celsius, Kelvin]
# Quadro4 Celcius(x50)                                           [Celsius, Kelvin]
# Quadro4 Celcius(x80)                                           [Celsius, Kelvin]
# Quadro4 Go                                                     [Celsius, Kelvin]
# Radeon IGP(2000)                                               [R400, TeraScale]
# Radeon Instinct(MIx)           [GCN 4.0, GCN 3.0, GCN 5.0, GCN 5.1, CDNA 1.0,...
# Radeon Pro GCN                                                [GCN 3.0, GCN 4.0]
# Radeon Pro Mac(Vega Series)                                   [GCN 5.0, GCN 5.1]
# Radeon Pro Polaris(WX x100)                                   [GCN 4.0, GCN 5.0]
# Radeon Pro Polaris(WX x200)                                   [GCN 5.0, GCN 4.0]
# Radeon R300(X550)                                                   [R300, R400]
# Rage 2                                                            [Mach, Rage 2]
# Rage 3                                                            [Rage 3, Mach]
# Rage Mobility                                                     [Mach, Rage 4]
# Sea Islands(HD 8500)                                      [TeraScale 2, GCN 1.0]
# Sea Islands(HD 8700)                                          [GCN 1.0, GCN 2.0]
# Server Blackwell(Bxx)                                 [Blackwell, Blackwell 2.0]
# Solar System(HD 8900M)                                        [GCN 2.0, GCN 1.0]
# Southern Islands(HD 7700)                        [GCN 1.0, TeraScale 2, GCN 2.0]
# Tesla Fermi(x20xx)                                            [Fermi, Fermi 2.0]
# Tesla Kepler(Kxx)                                           [Kepler, Kepler 2.0]
# Tesla Maxwell(Mxx)                                        [Maxwell 2.0, Maxwell]
# Volcanic Islands(R5 200)                                  [TeraScale 2, GCN 1.0]
# Volcanic Islands(R7 200)                                      [GCN 1.0, GCN 2.0]
# Volcanic Islands(R9 200)                             [GCN 1.0, GCN 3.0, GCN 2.0]
#
#                                count
# generation
# All-In-One(Rx 200)                 3
# All-In-One(Rx 300)                 2
# All-In-Wonder(2006 Edition)        2
# All-In-Wonder(7000)                2
# All-In-Wonder(9000)                2
# All-In-Wonder(X)                   2
# Arctic Islands(RX 400)             2
# Console GPU(AMD)                   3
# Console GPU(Microsoft)             5
# Console GPU(Nintendo)              5
# Console GPU(Sony)                  4
# Data Center GPU(Arctic Sound)      2
# Embedded(8000)                     3
# FireGL(9000)                       2
# FireGL(Vx100)                      2
# FireGL(Vx200)                      2
# FireMV Multi-View(2000)            4
# FirePro GCN(Wx100)                 3
# FirePro Mobile(Mx000)              2
# FirePro Mobile(Mx100)              2
# FirePro Mobile(Wx100M)             3
# FirePro Server(Sx100)              2
# FirePro Terascale(Vx900)           2
# GMA Graphics-M(GMA 3000 IGP)       2
# GRID(Mx)                           2
# GeForce 10                         3
# GeForce 100M                       2
# GeForce 20 Mobile                  2
# GeForce 200                        2
# GeForce 200M                       2
# GeForce 300                        2
# GeForce 300M                       2
# GeForce 40                         2
# GeForce 400                        3
# GeForce 400M                       3
# GeForce 500                        3
# GeForce 500M                       2
# GeForce 6 AGP(6200)                2
# GeForce 600                        4
# GeForce 600M                       3
# GeForce 700                        6
# GeForce 700A                       3
# GeForce 700M                       3
# GeForce 8(8400)                    2
# GeForce 800A                       3
# GeForce 800M                       4
# GeForce 9(9300)                    2
# GeForce 9(9400)                    2
# GeForce 900A                       2
# GeForce 900M                       3
# GeForce FX(5200)                   2
# GeForce MX(1xx)                    2
# GeForce MX(5xx)                    2
# GeForce PCX                        2
# GeForce4 Go                        2
# Gem System Hybrid(Rx M200)         2
# Gem System Hybrid(Rx M300)         2
# Gem System Hybrid(Rx M400)         2
# Gem System(R5 M200)                2
# Gem System(R5 M300)                2
# Gem System(R5 M400)                2
# Gem System(R7 M200)                2
# Gem System(R7 M300)                2
# Gem System(R7 M400)                2
# Gem System(R9 M200)                3
# Gem System(R9 M300)                3
# Gem System(R9 M400)                2
# Graphics                           2
# Graphics(IGP)                      2
# Graphics-M(IGP)                    2
# ION                                2
# M1x(Mobility 9000)                 2
# M2x(Mobility X1)                   2
# M7x(Mobility HD 2000)              2
# Mining GPUs                        4
# Mobility FireGL                    2
# Mobility FireGL(V5xxx)             3
# NVS                                4
# NVS Mobile                         2
# NVS Mobile(x200M)                  2
# Pirate Islands(R5 300)             2
# Pirate Islands(R7 300)             2
# Pirate Islands(R9 300)             3
# Polaris Mobile(M500)               3
# Polaris Mobile(M500X)              2
# Polaris Mobile(M600)               3
# Polaris(RX 500)                    2
# Polaris(RX 600)                    2
# Quadro FX Go                       2
# Quadro FX Mobile(x800M)            2
# Quadro FX Rankine(x000)            2
# Quadro FX Tesla(x600)              2
# Quadro FX Tesla(x800)              2
# Quadro Fermi(x000)                 3
# Quadro Fermi-M(x000M)              2
# Quadro Kepler(Kx200)               2
# Quadro Kepler-M(Kx100M)            2
# Quadro Maxwell-M(Mx000M)           2
# Quadro Maxwell-M(Mx200)            2
# Quadro NVS                         4
# Quadro2 Celcius                    2
# Quadro4 Celcius(x00)               2
# Quadro4 Celcius(x50)               2
# Quadro4 Celcius(x80)               2
# Quadro4 Go                         2
# Radeon IGP(2000)                   2
# Radeon Instinct(MIx)               8
# Radeon Pro GCN                     2
# Radeon Pro Mac(Vega Series)        2
# Radeon Pro Polaris(WX x100)        2
# Radeon Pro Polaris(WX x200)        2
# Radeon R300(X550)                  2
# Rage 2                             2
# Rage 3                             2
# Rage Mobility                      2
# Sea Islands(HD 8500)               2
# Sea Islands(HD 8700)               2
# Server Blackwell(Bxx)              2
# Solar System(HD 8900M)             2
# Southern Islands(HD 7700)          3
# Tesla Fermi(x20xx)                 2
# Tesla Kepler(Kxx)                  2
# Tesla Maxwell(Mxx)                 2
# Volcanic Islands(R5 200)           2
# Volcanic Islands(R7 200)           2
# Volcanic Islands(R9 200)           3

# %%
disp = get_association_df(df, 'architecture', 'gpu_name')

df[df['gpu_name']=='Condor']
df = df[~((df['gpu_name']=='Condor') & (df['architecture']=='G400'))] # remove all Condor chip products from G400 architecture
disp
# Out:
#           architecture  count
# gpu_name
# Condor    [G400, G500]      2

# %% [markdown]
# **Graphics**

# %%
disp = get_association_df(df, 'directx_major_version', 'gpu_name')
df = df[~((df['directx_major_version']==10.0) & (df['gpu_name']=='GT215'))] # remove the older GT215 chip product
disp
# Out:
#          directx_major_version  count
# gpu_name
# GT215             [10.0, 11.0]      2

# %%
disp = get_association_df(df, 'cuda_minor_version', 'gpu_name')
df = df[~((df['cuda_minor_version']==1.0) & (df['gpu_name']=='G92B'))] # remove the older G92B chip product
disp
# Out:
#          cuda_minor_version  count
# gpu_name
# G92B             [1.0, 3.0]      2

# %%
df.to_csv('../Source/Clean/2025-08.csv', index=False)
